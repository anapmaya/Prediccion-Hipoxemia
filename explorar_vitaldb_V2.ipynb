# %% [markdown]
# # ETL VitalDB
#
# ### En esta segunda versión de notebook, realizo las correcciones a la selección de variables sugeridas en la reunión con los médicos anestesiólogos.
#
# He descargado las tablas correspondientes a la base de datos VitalDB, de Physionet. **VitalDB** (Vital Signs DataBase) es un conjunto de datos abierto creado específicamente para facilitar estudios de aprendizaje automático relacionados con la monitorización de signos vitales en pacientes quirúrgicos.
#
# Este conjunto de datos contiene información multiparamétrica de alta resolución de 6,388 casos, incluyendo 486,451 registros de datos numéricos y de formas de onda de 196 parámetros de monitorización intraoperatoria, 73 parámetros clínicos perioperatorios y 34 parámetros de resultados de laboratorio en series de tiempo.
#
# En resumen, el conjunto de datos tiene las siguientes características:
#
# * El conjunto de datos consta de datos de signos vitales intraoperatorios e información clínica perioperatoria de 6,388 casos.
# * Los datos de signos vitales incluyen hasta 12 pistas de formas de onda y 184 pistas de datos numéricos obtenidos de múltiples dispositivos de anestesia aplicados a los pacientes durante la cirugía. El número total de pistas de datos es 486,451 (con un promedio de 87 y un rango de 16 a 129).
# * Los datos de signos vitales tienen varios intervalos de tiempo según los dispositivos de anestesia, con una resolución de tiempo de 1 a 7 segundos para los datos numéricos y de 62.5 a 500 Hz para los datos de formas de onda. Cada archivo de caso contiene un promedio de 2.8 millones de puntos de datos.
# * Los datos no están preprocesados porque el ruido del mundo real en los datos de signos vitales es esencial para el desarrollo de algoritmos de monitorización prácticos.
# * Se proporcionan un total de 74 parámetros de información clínica perioperatoria y 34 resultados de laboratorio perioperatorios en series de tiempo para ayudar a interpretar la relación con los signos vitales intraoperatorios.

# %%
# Importar librerías necesarias
import vitaldb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Observación exploratoria inicial de la base de datos
#
# El archivo vital es un archivo binario, grabado con el programa Vital Recorder, que contiene registros de series de tiempo de signos vitales. La especificación del formato del archivo vital se detalla en un documento dentro del repositorio de datos abierto.
#
# Un paquete de Python llamado "vitaldb", que ayuda a leer y escribir archivos vitales, está disponible de forma gratuita en PyPI, el índice de paquetes de Python.
#
# Después de instalar las librerías necesarias empiezo a explorar el contenido de mis carpetas.

# %%
# Configurar ruta donde tengo los archivos VitalDB
DATA_PATH = "/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0"
# Verificar que la ruta existe
if os.path.exists(DATA_PATH):
    print(f"Directorio encontrado: {DATA_PATH}")
    
    # Ver qué hay en el directorio principal
    contents = os.listdir(DATA_PATH)
    print(f"Contenido del directorio:")
    for item in contents:
        item_path = os.path.join(DATA_PATH, item)
        if os.path.isdir(item_path):
            print(f"  {item}/")
        else:
            print(f"  {item}")
    
    # Buscar archivos .vital en el directorio principal
    vital_files = [f for f in contents if f.endswith('.vital')]
    print(f"\nArchivos .vital encontrados en directorio principal: {len(vital_files)}")
    
    # Si no hay archivos .vital en el directorio principal, buscar en subdirectorios
    if len(vital_files) == 0:
        print("\nBuscando archivos .vital en subdirectorios...")
        for item in contents:
            item_path = os.path.join(DATA_PATH, item)
            if os.path.isdir(item_path):
                subdir_files = [f for f in os.listdir(item_path) if f.endswith('.vital')]
                if len(subdir_files) > 0:
                    print(f"  {item}/: {len(subdir_files)} archivos .vital")
    
else:
    print("Directorio no encontrado. Verificar ruta.")
# Out:
# Directorio encontrado: /Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0
# Contenido del directorio:
#   .DS_Store
#   lab_parameters.csv
#   track_names.csv
#   clinical_parameters.csv
#   lab_data.csv
#   vital_files/
#   clinical_data.csv
#   LICENSE.txt
#   SHA256SUMS.txt
#
# Archivos .vital encontrados en directorio principal: 0
#
# Buscando archivos .vital en subdirectorios...
#   vital_files/: 6388 archivos .vital

# %%
# Actualizar ruta a la carpeta que contiene los archivos .vital
VITAL_FILES_PATH = "/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0/vital_files"
CSV_PATH = "/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0"

# Verificar archivos .vital
vital_files = [f for f in os.listdir(VITAL_FILES_PATH) if f.endswith('.vital')]
print(f"Total de archivos .vital: {len(vital_files)}")
print(f"Primeros 5 archivos: {vital_files[:5]}")
# Out:
# Total de archivos .vital: 6388
# Primeros 5 archivos: ['4388.vital', '3698.vital', '3249.vital', '4759.vital', '1939.vital']

# %% [markdown]
# El archivo `clinical_data` proporciona datos perioperatorios relacionados con el paciente para ayudar a interpretar los datos de las bioseñales. Este archivo consta de un **ID de caso** y un **ID de paciente**, además de 72 parámetros clínicos que incluyen información del archivo del caso, datos demográficos, resultados, datos de laboratorio preoperatorios y datos relacionados con la cirugía y la anestesia.

# %%
#importo las tablas clinical_data y clinical_parameters
clinical_data_df = pd.read_csv('/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0/clinical_data.csv')
clinical_parameters_df = pd.read_csv('/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0/clinical_parameters.csv')

# %%
clinical_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6388 entries, 0 to 6387
# Data columns (total 74 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   caseid               6388 non-null   int64
#  1   subjectid            6388 non-null   int64
#  2   casestart            6388 non-null   int64
#  3   caseend              6388 non-null   int64
#  4   anestart             6388 non-null   int64
#  5   aneend               6388 non-null   float64
#  6   opstart              6388 non-null   int64
#  7   opend                6388 non-null   int64
#  8   adm                  6388 non-null   int64
#  9   dis                  6388 non-null   int64
#  10  icu_days             6388 non-null   int64
#  11  death_inhosp         6388 non-null   int64
#  12  age                  6388 non-null   object
#  13  sex                  6388 non-null   object
#  14  height               6388 non-null   float64
#  15  weight               6388 non-null   float64
#  16  bmi                  6388 non-null   float64
#  17  asa                  6255 non-null   float64
#  18  emop                 6388 non-null   int64
#  19  department           6388 non-null   object
#  20  optype               6388 non-null   object
#  21  dx                   6388 non-null   object
#  22  opname               6388 non-null   object
#  23  approach             6388 non-null   object
#  24  position             6194 non-null   object
#  25  ane_type             6388 non-null   object
#  26  preop_htn            6388 non-null   int64
#  27  preop_dm             6388 non-null   int64
#  28  preop_ecg            6388 non-null   object
#  29  preop_pft            6388 non-null   object
#  30  preop_hb             6047 non-null   float64
#  31  preop_plt            6047 non-null   float64
#  32  preop_pt             5998 non-null   float64
#  33  preop_aptt           5986 non-null   float64
#  34  preop_na             5765 non-null   float64
#  35  preop_k              5767 non-null   float64
#  36  preop_gluc           6010 non-null   float64
#  37  preop_alb            6016 non-null   float64
#  38  preop_ast            6022 non-null   float64
#  39  preop_alt            6024 non-null   float64
#  40  preop_bun            6023 non-null   float64
#  41  preop_cr             6016 non-null   float64
#  42  preop_ph             546 non-null    float64
#  43  preop_hco3           533 non-null    float64
#  44  preop_be             532 non-null    float64
#  45  preop_pao2           538 non-null    float64
#  46  preop_paco2          538 non-null    float64
#  47  preop_sao2           533 non-null    float64
#  48  cormack              5553 non-null   object
#  49  airway               5973 non-null   object
#  50  tubesize             4919 non-null   float64
#  51  dltubesize           930 non-null    object
#  52  lmasize              102 non-null    float64
#  53  iv1                  6313 non-null   object
#  54  iv2                  1437 non-null   object
#  55  aline1               3463 non-null   object
#  56  aline2               105 non-null    object
#  57  cline1               1541 non-null   object
#  58  cline2               60 non-null     object
#  59  intraop_ebl          3987 non-null   float64
#  60  intraop_uo           3707 non-null   float64
#  61  intraop_rbc          6388 non-null   int64
#  62  intraop_ffp          6388 non-null   int64
#  63  intraop_crystalloid  5980 non-null   float64
#  64  intraop_colloid      6388 non-null   int64
#  65  intraop_ppf          6388 non-null   int64
#  66  intraop_mdz          6388 non-null   float64
#  67  intraop_ftn          6388 non-null   int64
#  68  intraop_rocu         6388 non-null   int64
#  69  intraop_vecu         6388 non-null   int64
#  70  intraop_eph          6388 non-null   int64
#  71  intraop_phe          6388 non-null   int64
#  72  intraop_epi          6388 non-null   int64
#  73  intraop_ca           6388 non-null   int64
# dtypes: float64(29), int64(25), object(20)
# memory usage: 3.6+ MB

# %%
clinical_parameters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Parameter    81 non-null     object
#  1   Data Source  81 non-null     object
#  2   Description  81 non-null     object
#  3   Unit         53 non-null     object
# dtypes: object(4)
# memory usage: 2.7+ KB

# %% [markdown]
# ### Selección de operaciones torácicas con VUP
#
# Observando la columna `department` puedo extraer únicamente los registros que corresponden a cirugías torácicas.

# %%
cirugias_toracicas=clinical_data_df[clinical_data_df['department']=='Thoracic surgery']
cirugias_toracicas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1111 entries, 6 to 6375
# Data columns (total 74 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   caseid               1111 non-null   int64
#  1   subjectid            1111 non-null   int64
#  2   casestart            1111 non-null   int64
#  3   caseend              1111 non-null   int64
#  4   anestart             1111 non-null   int64
#  5   aneend               1111 non-null   float64
#  6   opstart              1111 non-null   int64
#  7   opend                1111 non-null   int64
#  8   adm                  1111 non-null   int64
#  9   dis                  1111 non-null   int64
#  10  icu_days             1111 non-null   int64
#  11  death_inhosp         1111 non-null   int64
#  12  age                  1111 non-null   object
#  13  sex                  1111 non-null   object
#  14  height               1111 non-null   float64
#  15  weight               1111 non-null   float64
#  16  bmi                  1111 non-null   float64
#  17  asa                  1082 non-null   float64
#  18  emop                 1111 non-null   int64
#  19  department           1111 non-null   object
#  20  optype               1111 non-null   object
#  21  dx                   1111 non-null   object
#  22  opname               1111 non-null   object
#  23  approach             1111 non-null   object
#  24  position             1095 non-null   object
#  25  ane_type             1111 non-null   object
#  26  preop_htn            1111 non-null   int64
#  27  preop_dm             1111 non-null   int64
#  28  preop_ecg            1111 non-null   object
#  29  preop_pft            1111 non-null   object
#  30  preop_hb             971 non-null    float64
#  31  preop_plt            966 non-null    float64
#  32  preop_pt             927 non-null    float64
#  33  preop_aptt           931 non-null    float64
#  34  preop_na             914 non-null    float64
#  35  preop_k              916 non-null    float64
#  36  preop_gluc           948 non-null    float64
#  37  preop_alb            946 non-null    float64
#  38  preop_ast            947 non-null    float64
#  39  preop_alt            945 non-null    float64
#  40  preop_bun            948 non-null    float64
#  41  preop_cr             950 non-null    float64
#  42  preop_ph             123 non-null    float64
#  43  preop_hco3           120 non-null    float64
#  44  preop_be             120 non-null    float64
#  45  preop_pao2           120 non-null    float64
#  46  preop_paco2          120 non-null    float64
#  47  preop_sao2           120 non-null    float64
#  48  cormack              1036 non-null   object
#  49  airway               1086 non-null   object
#  50  tubesize             199 non-null    float64
#  51  dltubesize           910 non-null    object
#  52  lmasize              2 non-null      float64
#  53  iv1                  1101 non-null   object
#  54  iv2                  402 non-null    object
#  55  aline1               1074 non-null   object
#  56  aline2               11 non-null     object
#  57  cline1               688 non-null    object
#  58  cline2               7 non-null      object
#  59  intraop_ebl          639 non-null    float64
#  60  intraop_uo           801 non-null    float64
#  61  intraop_rbc          1111 non-null   int64
#  62  intraop_ffp          1111 non-null   int64
#  63  intraop_crystalloid  1045 non-null   float64
#  64  intraop_colloid      1111 non-null   int64
#  65  intraop_ppf          1111 non-null   int64
#  66  intraop_mdz          1111 non-null   float64
#  67  intraop_ftn          1111 non-null   int64
#  68  intraop_rocu         1111 non-null   int64
#  69  intraop_vecu         1111 non-null   int64
#  70  intraop_eph          1111 non-null   int64
#  71  intraop_phe          1111 non-null   int64
#  72  intraop_epi          1111 non-null   int64
#  73  intraop_ca           1111 non-null   int64
# dtypes: float64(29), int64(25), object(20)
# memory usage: 651.0+ KB

# %% [markdown]
# También es posible seleccionar sólo las operaciones con Ventilación unipulmonar y el parámetro clave  es `dltubesize`.
#
# Este parámetro, que se encuentra en la columna "Parameter", tiene la descripción "Double lumen tube size" (tamaño del tubo de doble luz) y la unidad "Fr" (French). Un tubo de doble luz se utiliza específicamente para la ventilación unipulmonar.

# %%
# Suponiendo que tu DataFrame se llama clinical_parameters_df
descripcion = clinical_parameters_df.loc[clinical_parameters_df['Parameter'] == 'dltubesize', 'Description'].iloc[0]

print(descripcion)
# Out:
# Double lumen tube size

# %% [markdown]
# Para filtrar los casos que utilizaron ventilación unipulmonar, voy a extraer las filas donde la columna dltubesize contenga un valor. Si el valor es nulo (NaN), significa que no se usó un tubo de doble luz, por lo que no hubo ventilación unipulmonar. Si el valor no es nulo, es una fuerte indicación de que se utilizó SLV.

# %%
cirugias_VUP = cirugias_toracicas[cirugias_toracicas['dltubesize'].notna()]
cirugias_VUP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 910 entries, 6 to 6375
# Data columns (total 74 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   caseid               910 non-null    int64
#  1   subjectid            910 non-null    int64
#  2   casestart            910 non-null    int64
#  3   caseend              910 non-null    int64
#  4   anestart             910 non-null    int64
#  5   aneend               910 non-null    float64
#  6   opstart              910 non-null    int64
#  7   opend                910 non-null    int64
#  8   adm                  910 non-null    int64
#  9   dis                  910 non-null    int64
#  10  icu_days             910 non-null    int64
#  11  death_inhosp         910 non-null    int64
#  12  age                  910 non-null    object
#  13  sex                  910 non-null    object
#  14  height               910 non-null    float64
#  15  weight               910 non-null    float64
#  16  bmi                  910 non-null    float64
#  17  asa                  884 non-null    float64
#  18  emop                 910 non-null    int64
#  19  department           910 non-null    object
#  20  optype               910 non-null    object
#  21  dx                   910 non-null    object
#  22  opname               910 non-null    object
#  23  approach             910 non-null    object
#  24  position             901 non-null    object
#  25  ane_type             910 non-null    object
#  26  preop_htn            910 non-null    int64
#  27  preop_dm             910 non-null    int64
#  28  preop_ecg            910 non-null    object
#  29  preop_pft            910 non-null    object
#  30  preop_hb             793 non-null    float64
#  31  preop_plt            792 non-null    float64
#  32  preop_pt             758 non-null    float64
#  33  preop_aptt           761 non-null    float64
#  34  preop_na             745 non-null    float64
#  35  preop_k              746 non-null    float64
#  36  preop_gluc           775 non-null    float64
#  37  preop_alb            774 non-null    float64
#  38  preop_ast            774 non-null    float64
#  39  preop_alt            773 non-null    float64
#  40  preop_bun            775 non-null    float64
#  41  preop_cr             777 non-null    float64
#  42  preop_ph             85 non-null     float64
#  43  preop_hco3           83 non-null     float64
#  44  preop_be             83 non-null     float64
#  45  preop_pao2           83 non-null     float64
#  46  preop_paco2          83 non-null     float64
#  47  preop_sao2           83 non-null     float64
#  48  cormack              882 non-null    object
#  49  airway               907 non-null    object
#  50  tubesize             29 non-null     float64
#  51  dltubesize           910 non-null    object
#  52  lmasize              0 non-null      float64
#  53  iv1                  909 non-null    object
#  54  iv2                  331 non-null    object
#  55  aline1               906 non-null    object
#  56  aline2               10 non-null     object
#  57  cline1               588 non-null    object
#  58  cline2               6 non-null      object
#  59  intraop_ebl          517 non-null    float64
#  60  intraop_uo           677 non-null    float64
#  61  intraop_rbc          910 non-null    int64
#  62  intraop_ffp          910 non-null    int64
#  63  intraop_crystalloid  863 non-null    float64
#  64  intraop_colloid      910 non-null    int64
#  65  intraop_ppf          910 non-null    int64
#  66  intraop_mdz          910 non-null    float64
#  67  intraop_ftn          910 non-null    int64
#  68  intraop_rocu         910 non-null    int64
#  69  intraop_vecu         910 non-null    int64
#  70  intraop_eph          910 non-null    int64
#  71  intraop_phe          910 non-null    int64
#  72  intraop_epi          910 non-null    int64
#  73  intraop_ca           910 non-null    int64
# dtypes: float64(29), int64(25), object(20)
# memory usage: 533.2+ KB

# %% [markdown]
# Encuentro que de los 6388 casos almacenados en la base de datos, 1111 son cirugías torácicas. Y de estas, 910 utilizaron tubo de doble luz, es decir, se realizaron con ventilación uni pulmonar (VUP).
# De esta manera llego a tener las cirugías con las que voy a trabajar: **Cirugías Torácicas con Ventilación Unipulmonar**

# %% [markdown]
# ### 3. Análisis de características demográficas.
#
# Conteo de pacientes según edad, sexo, ASA, peso, estatura, BMI.
#
# PD3: El ASA Physical Status Classification System (o estado físico ASA) es una escala desarrollada por la American Society of Anesthesiologists (ASA) para clasificar el estado físico general de un paciente antes de una cirugía o procedimiento anestésico. Sirve para que anestesiólogos y cirujanos evalúen qué tan riesgosa puede ser la anestesia y la cirugía según las condiciones de salud del paciente, independientemente del tipo de cirugía.
#
# Escala ASA Physical Status
# - ASA I – Paciente sano, sin enfermedad sistémica, no fumador, sin consumo de alcohol o drogas.
# - ASA II – Paciente con enfermedad sistémica leve (p. ej., hipertensión controlada, diabetes bien controlada, fumador social).
# - ASA III – Paciente con enfermedad sistémica grave que limita su actividad pero no lo incapacita por completo (p. ej., angina estable, EPOC moderada, insuficiencia cardíaca controlada).
# - ASA IV – Paciente con enfermedad sistémica grave que amenaza la vida (p. ej., insuficiencia cardíaca descompensada, sepsis grave).
# - ASA V – Paciente moribundo, que probablemente no sobreviva 24 horas con o sin cirugía (p. ej., aneurisma roto, trauma masivo).
# - ASA VI – Paciente con muerte cerebral que será sometido a extracción de órganos para trasplante.
# - Además, se añade la letra E (Emergency) si la cirugía es de urgencia.Ejemplo: “ASA IIIE” = paciente con enfermedad sistémica grave, en cirugía de emergencia.

# %%
# 1. Convertir la columna 'age' a tipo numérico, forzando errores a NaN
cirugias_VUP['age'] = pd.to_numeric(cirugias_VUP['age'], errors='coerce')

# %%
# Análisis de características demográficas

def analyze_demographics(cirugias_VUP):
    
    print("\n=== ANÁLISIS DEMOGRÁFICO ===")
    
    # Distribución por edad
    print(f"\nEstadísticas de edad:")
    print(cirugias_VUP['age'].describe())
    
    # Distribución por sexo
    print(f"\nDistribución por sexo:")
    sex_dist = cirugias_VUP['sex'].value_counts()
    print(sex_dist)
    print(f"Porcentaje masculino: {sex_dist.get('M', 0)/len(cirugias_VUP)*100:.1f}%")
    
    # ASA Physical Status
    print(f"\nDistribución ASA-PS:")
    asa_dist = cirugias_VUP['asa'].value_counts().sort_index()
    for asa, count in asa_dist.items():
        print(f"  ASA {asa}: {count:,} ({count/len(cirugias_VUP)*100:.1f}%)")
    
    # Peso
    print(f"\nEstadísticas de peso:")
    print(cirugias_VUP['weight'].describe())

    # Estatura
    print(f"\nEstadísticas de estatura:")
    print(cirugias_VUP['height'].describe())    

    # BMI
    print(f"\nEstadísticas de BMI:")
    print(cirugias_VUP['bmi'].describe())

# %%
analyze_demographics(cirugias_VUP)
# Out:
# === ANÁLISIS DEMOGRÁFICO ===
#
# Estadísticas de edad:
# count    910.000000
# mean      59.316484
# std       13.813183
# min       16.000000
# 25%       52.000000
# 50%       61.000000
# 75%       69.000000
# max       89.000000
# Name: age, dtype: float64
#
# Distribución por sexo:
# sex
# M    505
# F    405
# Name: count, dtype: int64
# Porcentaje masculino: 55.5%
#
# Distribución ASA-PS:
#   ASA 1.0: 162 (17.8%)
#   ASA 2.0: 612 (67.3%)
#   ASA 3.0: 97 (10.7%)
#   ASA 4.0: 4 (0.4%)
#   ASA 6.0: 9 (1.0%)
#
# Estadísticas de peso:
# count    910.000000
# mean      62.011209
# std       10.369091
# min       34.000000
# 25%       54.400000
# 50%       61.100000
# 75%       68.700000
# max       98.000000
# Name: weight, dtype: float64
#
# Estadísticas de estatura:
# count    910.000000
# mean     162.922527
# std        8.563554
# min      138.400000
# 25%      156.400000
# 50%      163.250000
# 75%      169.175000
# max      186.000000
# Name: height, dtype: float64
#
# Estadísticas de BMI:
# count    910.000000
# mean      23.330110
# std        3.244648
# min       14.500000
# 25%       21.100000
# 50%       23.200000
# 75%       25.400000
# max       35.700000
# Name: bmi, dtype: float64

# %% [markdown]
# De lo anterior puedo observar que:
#
# * La mayoría de los individuos en la muestra son del **sexo masculino**, representando aproximadamente el 55.5% del total.
# * El promedio de edad son  **59 años**, siendo la edad mínima 16 y la máxima 89 años.
# * La mayoría de los pacientes se clasifican con un **estado físico ASA 2.0** (67.3%), lo que indica la presencia de una enfermedad sistémica leve que no limita la actividad.
# * El **BMI promedio** es de 23.3, lo que se encuentra dentro del rango de peso normal.

# %% [markdown]
# ### Características de las cirugías
#
# Voy a revisar los siguientes aspectos:
# - Duración de la cirugía
# - Duración de la anestesia
# - Duración del caso
# - Tipo de anestesia
# - Approach
# - Posición

# %%
# Calculo la duración de la operación restando tiempo de inicio y tiempo de finalización
# Creo la columna 'dur_op_seg'

if 'opstart' in cirugias_VUP.columns and 'opend' in cirugias_VUP.columns:
    cirugias_VUP['dur_op_seg'] = cirugias_VUP['opend'] - cirugias_VUP['opstart']
        
    print("Duración de cirugía (segundos):")
    print(cirugias_VUP['dur_op_seg'].describe())

# Calculo la duración de la anestesia restando tiempo de inicio y tiempo de finalización
# Creo la columna 'dur_anest_seg'

if 'anestart' in cirugias_VUP.columns and 'aneend' in cirugias_VUP.columns:
    cirugias_VUP['dur_anest_seg'] = cirugias_VUP['aneend'] - cirugias_VUP['anestart']
        
    print(f"\nDuración de anestesia (segundos):")
    print(cirugias_VUP['dur_anest_seg'].describe())    

# Calculo la duración de cada caso restando tiempo de inicio y tiempo de finalización
# Creo la columna 'dur_case_seg'

if 'casestart' in cirugias_VUP.columns and 'caseend' in cirugias_VUP.columns:
    cirugias_VUP['dur_case_seg'] = cirugias_VUP['caseend'] - cirugias_VUP['casestart']
        
    print(f"\nDuración de caso (segundos):")
    print(cirugias_VUP['dur_case_seg'].describe()) 

#Observo la distribución de las cirugías según el tipo de anestesia
print(f"\nTipo de anestesia:")
anest_types = cirugias_VUP['ane_type'].value_counts()
for atype, count in anest_types.items():
    print(f"  {atype}: {count:,} ({count/len(cirugias_VUP)*100:.1f}%)")

#Observo la distribución de las cirugías según approach
print(f"\nApproach:")
anest_types = cirugias_VUP['approach'].value_counts()
for atype, count in anest_types.items():
    print(f"  {atype}: {count:,} ({count/len(cirugias_VUP)*100:.1f}%)")    

#Observo la distribución de las cirugías según la posición
print(f"\nPosición:")
anest_types = cirugias_VUP['position'].value_counts()
for atype, count in anest_types.items():
    print(f"  {atype}: {count:,} ({count/len(cirugias_VUP)*100:.1f}%)")
# Out:
# Duración de cirugía (segundos):
# count      910.000000
# mean      7930.918681
# std       5639.708936
# min       1200.000000
# 25%       4500.000000
# 50%       6900.000000
# 75%       9657.000000
# max      57300.000000
# Name: dur_op_seg, dtype: float64
#
# Duración de anestesia (segundos):
# count      910.000000
# mean     12371.142857
# std       6249.969066
# min       3480.000000
# 25%       8355.000000
# 50%      11640.000000
# 75%      14700.000000
# max      65700.000000
# Name: dur_anest_seg, dtype: float64
#
# Duración de caso (segundos):
# count      910.000000
# mean     11811.790110
# std       6200.132358
# min       3159.000000
# 25%       7754.750000
# 50%      10831.500000
# 75%      14177.750000
# max      62494.000000
# Name: dur_case_seg, dtype: float64
#
# Tipo de anestesia:
#   General: 910 (100.0%)
#
# Approach:
#   Videoscopic: 771 (84.7%)
#   Open: 117 (12.9%)
#   Robotic: 22 (2.4%)
#
# Posición:
#   Left lateral decubitus: 472 (51.9%)
#   Right lateral decubitus: 338 (37.1%)
#   Supine: 87 (9.6%)
#   Sitting: 3 (0.3%)
#   Prone: 1 (0.1%)

# %% [markdown]
# ### Limpieza de datos tabla cirugías VUP - Valores nulos

# %%
# 1. INFORMACIÓN BÁSICA
print("\n1. INFORMACIÓN BÁSICA")
print("-" * 30)
print(f"Shape total: {cirugias_VUP.shape}")
print(f"Pacientes únicos: {cirugias_VUP['subjectid'].nunique()}")
print(f"Cirugías únicas: {cirugias_VUP['caseid'].nunique()}")
# Out:
# 1. INFORMACIÓN BÁSICA
# ------------------------------
# Shape total: (910, 77)
# Pacientes únicos: 882
# Cirugías únicas: 910

# %%
# 2. VALORES FALTANTES
print("\n2. ANÁLISIS DE VALORES FALTANTES")
print("-" * 40)
missing_analysis = cirugias_VUP.isnull().sum()
missing_pct = (missing_analysis / len(cirugias_VUP)) * 100
missing_df = pd.DataFrame({
        'Missing_Count': missing_analysis,
        'Missing_Pct': missing_pct
    }).sort_values('Missing_Pct', ascending=False)
    
print("Columnas con valores faltantes:")
print(missing_df[missing_df['Missing_Count'] > 0])
# Out:
# 2. ANÁLISIS DE VALORES FALTANTES
# ----------------------------------------
# Columnas con valores faltantes:
#                      Missing_Count  Missing_Pct
# lmasize                        910   100.000000
# cline2                         904    99.340659
# aline2                         900    98.901099
# tubesize                       881    96.813187
# preop_sao2                     827    90.879121
# preop_paco2                    827    90.879121
# preop_pao2                     827    90.879121
# preop_be                       827    90.879121
# preop_hco3                     827    90.879121
# preop_ph                       825    90.659341
# iv2                            579    63.626374
# intraop_ebl                    393    43.186813
# cline1                         322    35.384615
# intraop_uo                     233    25.604396
# preop_na                       165    18.131868
# preop_k                        164    18.021978
# preop_pt                       152    16.703297
# preop_aptt                     149    16.373626
# preop_alt                      137    15.054945
# preop_alb                      136    14.945055
# preop_ast                      136    14.945055
# preop_bun                      135    14.835165
# preop_gluc                     135    14.835165
# preop_cr                       133    14.615385
# preop_plt                      118    12.967033
# preop_hb                       117    12.857143
# intraop_crystalloid             47     5.164835
# cormack                         28     3.076923
# asa                             26     2.857143
# position                         9     0.989011
# aline1                           4     0.439560
# airway                           3     0.329670
# iv1                              1     0.109890

# %% [markdown]
# Voy a revisar la tabla de parámetros clínicos para conocer la descripción de los parámetros que tienen datos faltantes

# %%
# 1. Obtener la lista de parámetros con valores faltantes
# La lista de parámetros con valores faltantes se encuentra en el índice
# del DataFrame `missing_df`.
missing_parameters = missing_df[missing_df['Missing_Count'] > 0].index.tolist()

# 3. Filtrar el DataFrame clinical_parameters para obtener las descripciones
# Se usa el método isin() para buscar cada uno de los parámetros de la lista
descriptions_of_missing_params = clinical_parameters_df[
    clinical_parameters_df['Parameter'].isin(missing_parameters)
]

# 4. Imprimir los resultados
print("\nDescripciones de los parámetros con valores faltantes:")
print("-" * 50)
print(descriptions_of_missing_params[['Parameter', 'Description']])
# Out:
# Descripciones de los parámetros con valores faltantes:
# --------------------------------------------------
#               Parameter                         Description
# 17                  asa  ASA Physical status classification
# 24             position                   Surgical position
# 37             preop_hb             Preoperative hemoglobin
# 38            preop_plt         Preoperative platelet count
# 39             preop_pt                     Preoperative PT
# 40           preop_aptt                   Preoperative aPTT
# 41             preop_na                     Preoperative Na
# 42              preop_k                      Preoperative K
# 43           preop_gluc                Preoperative glucose
# 44            preop_alb                Preoperative albumin
# 45            preop_ast                    Preoperative GOT
# 46            preop_alt                    Preoperative GPT
# 47            preop_bun    Preoperative blood urea nitrogen
# 48             preop_cr             Preoperative creatinine
# 49             preop_ph                     Preoperative pH
# 50           preop_hco3                  Preoperative HCO3-
# 51             preop_be            Preoperative base excess
# 52           preop_pao2                   Preoperative PaO2
# 53          preop_paco2                  Preoperative PaCO2
# 54           preop_sao2                   Preoperative SpO2
# 55              cormack                     Cormack's grade
# 56               airway                        Airway route
# 57             tubesize              Endotracheal tube size
# 59              lmasize                            LMA size
# 60                  iv1                 Site of IV line (1)
# 61                  iv2                 Site of IV line (2)
# 62               aline1           Site of arterial line (1)
# 63               aline2           Site of arterial line (2)
# 64               cline1            Site of central line (1)
# 65               cline2            Site of central line (2)
# 66          intraop_ebl                Estimated blood loss
# 67           intraop_uo         Intraoperative urine output
# 70  intraop_crystalloid          Intraoperative crystalloid

# %% [markdown]
# Las que  tienen más del 90% de valores nulos son:
#
# LMA size(lmasize)
#
# cline2 (Site of central line (2))
#
# aline2 (Site of arterial line (2))
#
# tubesize (Endotracheal tube size)
#
# preop_pao2 (Preoperative PaO2)
#
# preop_be (Preoperative base excess)
#
# preop_hco3 (Preoperative HCO3)
#
# preop_sao2 (Preoperative SpO2)
#
# preop_paco2 (Preoperative PaCO2)
#
# preop_ph (Preoperative pH)
#
# Decido eliminar estas columnas, porque unas tienen que ver con información que no existe debido al tipo de operación, y otras son valores pre-operatorios. Parámetros como preop_pao2, preop_paco2, preop_ph, preop_sao2, preop_hco3 y preop_be se obtienen de análisis de gases arteriales.  Este tipo de prueba es invasiva y no se realiza de forma rutinaria en todos los pacientes antes de la cirugía.
#
# También están las siguientes con porcentajes de cantidad de nulos entre 63.6% y 12.8%
#
# iv2 (Site of IV line (2))
#
# intraop_ebl (Estimated blood loss)
#
# cline1 (Site of central line (1))
#
# intraop_uo (Intraoperative urine output)
#
# preop_na (Preoperative Na)
#
# preop_k (Preoperative K)
#
# preop_pt (Preoperative PT)
#
# preop_aptt (Preoperative aPTT)
#
# preop_alt (Preoperative GPT)
#
# preop_ast (Preoperative GOT)
#
# preop_alb (Preoperative albumin)
#
# preop_bun (Preoperative blood urea nitrogen)
#
# preop_gluc (Preoperative glucose)
#
# preop_cr (Preoperative creatinine)
#
# preop_plt (Preoperative platelet count)
#
# preop_hb (Preoperative hemoglobin)
#
# Columnas a eliminar: ['lmasize', 'cline1', 'cline2', 'aline2', 'tubesize', 'iv2', 'preop_pao2', 'preop_be', 'preop_hco3', 'preop_sao2', 'preop_paco2', 'preop_ph', 'intraop_ebl', 'intraop_uo', 'preop_na', 'preop_k', 'preop_pt', 'preop_aptt', 'preop_alt', 'preop_ast', 'preop_alb', 'preop_bun', 'preop_gluc', 'preop_cr', 'preop_plt'].
#
# Tomo esta decisión pues los porcentajes de datos nulos son muy elevados y/o porque además no son variables que vaya a utilizar en mi modelo de ML

# %%
columnas_a_eliminar = ['lmasize', 'cline1', 'cline2', 'aline2', 'tubesize', 'iv2', 'preop_pao2', 'preop_be',
'preop_hco3', 'preop_sao2', 'preop_paco2', 'preop_ph', 'intraop_ebl', 'intraop_uo', 'preop_na', 
'preop_k', 'preop_pt', 'preop_aptt', 'preop_alt', 'preop_ast', 'preop_alb', 'preop_bun', 
'preop_gluc', 'preop_cr', 'preop_plt']

# Crear un nuevo DataFrame con las columnas eliminadas
cirugias_VUP_filtrado = cirugias_VUP.drop(columns=columnas_a_eliminar)

# Verificar que el DataFrame original no ha cambiado
print(f"Número de columnas en el DataFrame original: {cirugias_VUP.shape[1]}")

# Verificar el nuevo DataFrame
print(f"Número de columnas en el nuevo DataFrame: {cirugias_VUP_filtrado.shape[1]}")
# Out:
# Número de columnas en el DataFrame original: 77
# Número de columnas en el nuevo DataFrame: 52

# %%
#Vuelvo a consultar valores faltantes
# 2. VALORES FALTANTES
print("\n2. ANÁLISIS DE VALORES FALTANTES")
print("-" * 40)
missing_analysis = cirugias_VUP_filtrado.isnull().sum()
missing_pct = (missing_analysis / len(cirugias_VUP_filtrado)) * 100
missing_df = pd.DataFrame({
        'Missing_Count': missing_analysis,
        'Missing_Pct': missing_pct
    }).sort_values('Missing_Pct', ascending=False)
    
print("Columnas con valores faltantes:")
print(missing_df[missing_df['Missing_Count'] > 0])
# Out:
# 2. ANÁLISIS DE VALORES FALTANTES
# ----------------------------------------
# Columnas con valores faltantes:
#                      Missing_Count  Missing_Pct
# preop_hb                       117    12.857143
# intraop_crystalloid             47     5.164835
# cormack                         28     3.076923
# asa                             26     2.857143
# position                         9     0.989011
# aline1                           4     0.439560
# airway                           3     0.329670
# iv1                              1     0.109890

# %% [markdown]
# De estas columnas me parece relevante conservarlas preop_hb, asa y position, así que voy a manejar los datos nulos con técnicas de imputación de datos.
#
# Las demas columnas las elimino pues en la verificacion de variables realizada con los médicos anestesiólogos, se sugirió que no eran determinantes para la predicción de hipoxemia. También elimino columnas que, aunque no tienen datos nulos, también fueron identificadas como poco relevantes: 'subjectid', 'opstart', 'opend', 'adm', 'dis', 'icu_days', 'death_inhosp', 'optype', 'dx', 'opname', 'intraop_colloid'

# %%
columnas_a_eliminar2 = ['intraop_crystalloid', 'cormack', 'aline1', 'airway', 'iv1', 'subjectid', 
                        'opstart', 'opend', 'adm', 'dis', 'icu_days', 'death_inhosp', 'optype', 'dx', 'opname', 'intraop_colloid']

# Crear un nuevo DataFrame con las columnas eliminadas
cirugias_VUP_filtrado2 = cirugias_VUP_filtrado.drop(columns=columnas_a_eliminar2)

# Verificar que el DataFrame original no ha cambiado
print(f"Número de columnas en el DataFrame original: {cirugias_VUP_filtrado.shape[1]}")

# Verificar el nuevo DataFrame
print(f"Número de columnas en el nuevo DataFrame: {cirugias_VUP_filtrado2.shape[1]}")
# Out:
# Número de columnas en el DataFrame original: 52
# Número de columnas en el nuevo DataFrame: 36

# %%
# Imputar la hemoglobina preoperatoria
mediana_hb = cirugias_VUP_filtrado2['preop_hb'].median()
cirugias_VUP_filtrado2['preop_hb'].fillna(mediana_hb, inplace=True)

# %% [markdown]
# Para las variables categóricas, `asa` y `position`, la mejor opción es la imputación por la moda (el valor más frecuente). Al reemplazar los valores nulos con la categoría que más se repite, estoy manteniendo la distribución original de la variable y evito introducir nuevos valores que no existen en el conjunto de datos.

# %%
# Definir la lista de variables categóricas a imputar
columnas_categoricas = ['asa', 'position']

for col in columnas_categoricas:
    moda_col = cirugias_VUP_filtrado2[col].mode()[0]
    cirugias_VUP_filtrado2[col].fillna(moda_col, inplace=True)

# %%
#Vuelvo a consultar valores faltantes
# 2. VALORES FALTANTES
print("\n2. ANÁLISIS DE VALORES FALTANTES")
print("-" * 40)
missing_analysis = cirugias_VUP_filtrado2.isnull().sum()
missing_pct = (missing_analysis / len(cirugias_VUP_filtrado2)) * 100
missing_df = pd.DataFrame({
        'Missing_Count': missing_analysis,
        'Missing_Pct': missing_pct
    }).sort_values('Missing_Pct', ascending=False)
    
print("Columnas con valores faltantes:")
print(missing_df[missing_df['Missing_Count'] > 0])
# Out:
# 2. ANÁLISIS DE VALORES FALTANTES
# ----------------------------------------
# Columnas con valores faltantes:
# Empty DataFrame
# Columns: [Missing_Count, Missing_Pct]
# Index: []

# %% [markdown]
# ### Limpieza de datos tabla cirugías VUP - Registros duplicados

# %%
# ANÁLISIS DE REGISTROS DUPLICADOS
# Duplicados exactos
print("\n3. ANÁLISIS DE REGISTROS DUPLICADOS")
print("-" * 40)
exact_duplicates = cirugias_VUP_filtrado2.duplicated().sum()
print(f"Registros duplicados exactos: {exact_duplicates:,}")
# Out:
# 3. ANÁLISIS DE REGISTROS DUPLICADOS
# ----------------------------------------
# Registros duplicados exactos: 0

# %%
print("\n1. INFORMACIÓN BÁSICA DE LOS DATOS SIN NULOS NI REPETIDOS")
print("-" * 30)
print(f"Shape total: {cirugias_VUP_filtrado2.shape}")
print(f"Cirugías únicas: {cirugias_VUP_filtrado2['caseid'].nunique()}")
# Out:
# 1. INFORMACIÓN BÁSICA DE LOS DATOS SIN NULOS NI REPETIDOS
# ------------------------------
# Shape total: (910, 36)
# Cirugías únicas: 910

# %% [markdown]
# Tengo una tabla que contiene 36 parámetros pre-operatorios de 910 cirugías. No hay datos nulos ni registros duplicados.

# %%
cirugias_VUP_filtrado2.head()
# Out:
#     caseid  casestart  caseend  anestart   aneend  age sex  height  weight  \
# 6        7          0    15770       477  14817.0   52   F   167.7    62.3
# 12      13          0    10811      -703  10697.0   67   F   153.0    64.9
# 19      20          0    26476        86  27086.0   75   M   173.6    61.3
# 25      26          0    10711      -518  10282.0   64   M   169.7    62.6
# 27      28          0    26902      -258  27162.0   67   F   148.9    49.9
#
#      bmi  ...  intraop_ftn  intraop_rocu intraop_vecu intraop_eph intraop_phe  \
# 6   22.2  ...            0           120            0           0           0
# 12  27.7  ...            0            95            0           0           0
# 19  20.3  ...            0           180            0           5         250
# 25  21.7  ...            0           120            0           0           0
# 27  22.5  ...            0           170            0           0         400
#
#    intraop_epi  intraop_ca  dur_op_seg dur_anest_seg dur_case_seg
# 6            0           0       11400       14340.0        15770
# 12           0           0        6180       11400.0        10811
# 19           0         600       22489       27000.0        26476
# 25           0           0        6600       10800.0        10711
# 27           0           0       22800       27420.0        26902
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Exploracion de las tablas .vital
#
# Voy a observar el primer archivo de mi tabla, cuyo caseid es 0007. Voy a ingresar manualmente el path en la función, para hacer una observación preliminar. Quiero extraer las siguientes variables:'spo2', 'etco2', 'fio2', 'vt', 'pip', 'hr', 'rr'.
#
# Observando la tabla de `track_names`encuentro que lo nombres de estas variables en las tablas de vitals son los siguientes:
#
# 'Solar8000/ETCO2','Solar8000/FEO2','Solar8000/FIO2','Solar8000/HR','Solar8000/INCO2','Solar8000/RR','Solar8000/RR_CO2','Solar8000/VENT_RR','Solar8000/PLETH_SPO2','Solar8000/PLETH_HR','Solar8000/VENT_PIP','Solar8000/VENT_TV'
#
# También, por recomendaciónde los médicos anestesiólogos, quiero observar MAC (Minimum alveolar concentration of volatile), CI (Cardiac Index) y CO (Cardiac Output):
#
# 'Primus/MAC','Vigileo/CI','Vigileo/CO','EV1000/CI','EV1000/CO','CardioQ/CI','CardioQ/CO','Vigilance/CI','Vigilance/CO'

# %%
#El caseid de la primera cirugía que quiero observar es 7. Los nombres de los archivos tienen 4 caracteres
# es decir el nombre de este archivo es 0007.vital
archivo_cargar = '/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0/vital_files/0007.vital'
parametros = ['Solar8000/ETCO2','Solar8000/FEO2','Solar8000/FIO2','Solar8000/HR','Solar8000/INCO2','Solar8000/RR','Solar8000/RR_CO2','Solar8000/VENT_RR','Solar8000/PLETH_SPO2','Solar8000/PLETH_HR','Solar8000/VENT_PIP','Solar8000/VENT_TV','Primus/MAC','Vigileo/CI','Vigileo/CO','EV1000/CI','EV1000/CO','CardioQ/CI','CardioQ/CO','Vigilance/CI','Vigilance/CO']

# 2. Llamo a la función VitalFile y asigno el resultado a una variable
#tomo un intervalo de 10 seg. Intenté con 1 pero me devolvía muchos datos nulos. Luego intenté con 10 y 20seg
# y la cantidad de datos nulos era la misma, entonces me quedo con el valor de 10seg para el intervalo
datos_de_cirugia = vitaldb.VitalFile(archivo_cargar).to_pandas (parametros, interval = 10)

# 3. Ahora puedo trabajar con la variable 'datos_de_cirugia'
datos_de_cirugia.head()
# Out:
#    Solar8000/ETCO2  Solar8000/FEO2  Solar8000/FIO2  Solar8000/HR  \
# 0              1.0            21.0            21.0          65.0
# 1              1.0            21.0            21.0          68.0
# 2              1.0            21.0            21.0          67.0
# 3              1.0            21.0            21.0          67.0
# 4              1.0            21.0            21.0          67.0
#
#    Solar8000/INCO2  Solar8000/RR  Solar8000/RR_CO2  Solar8000/VENT_RR  \
# 0              1.0           NaN               NaN                NaN
# 1              1.0           NaN               NaN                NaN
# 2              1.0           NaN               NaN                NaN
# 3              1.0           NaN               NaN                NaN
# 4              1.0           NaN               NaN                NaN
#
#    Solar8000/PLETH_SPO2  Solar8000/PLETH_HR  ...  Solar8000/VENT_TV  \
# 0                  61.0                99.0  ...                NaN
# 1                   NaN                 NaN  ...                NaN
# 2                  65.0               101.0  ...                NaN
# 3                  65.0               101.0  ...                NaN
# 4                   NaN                 NaN  ...                NaN
#
#    Primus/MAC  Vigileo/CI  Vigileo/CO  EV1000/CI  EV1000/CO  CardioQ/CI  \
# 0         0.0         NaN         NaN        NaN        NaN         NaN
# 1         0.0         NaN         NaN        NaN        NaN         NaN
# 2         0.0         NaN         NaN        NaN        NaN         NaN
# 3         0.0         NaN         NaN        NaN        NaN         NaN
# 4         0.0         NaN         NaN        NaN        NaN         NaN
#
#    CardioQ/CO  Vigilance/CI  Vigilance/CO
# 0         NaN           NaN           NaN
# 1         NaN           NaN           NaN
# 2         NaN           NaN           NaN
# 3         NaN           NaN           NaN
# 4         NaN           NaN           NaN
#
# [5 rows x 21 columns]

# %%
datos_de_cirugia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577 entries, 0 to 1576
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Solar8000/ETCO2       1514 non-null   float64
#  1   Solar8000/FEO2        1514 non-null   float64
#  2   Solar8000/FIO2        1514 non-null   float64
#  3   Solar8000/HR          1467 non-null   float64
#  4   Solar8000/INCO2       1514 non-null   float64
#  5   Solar8000/RR          0 non-null      float64
#  6   Solar8000/RR_CO2      1395 non-null   float64
#  7   Solar8000/VENT_RR     1397 non-null   float64
#  8   Solar8000/PLETH_SPO2  1518 non-null   float64
#  9   Solar8000/PLETH_HR    1518 non-null   float64
#  10  Solar8000/VENT_PIP    1359 non-null   float64
#  11  Solar8000/VENT_TV     1390 non-null   float64
#  12  Primus/MAC            1510 non-null   float64
#  13  Vigileo/CI            0 non-null      float64
#  14  Vigileo/CO            0 non-null      float64
#  15  EV1000/CI             0 non-null      float64
#  16  EV1000/CO             0 non-null      float64
#  17  CardioQ/CI            0 non-null      float64
#  18  CardioQ/CO            0 non-null      float64
#  19  Vigilance/CI          0 non-null      float64
#  20  Vigilance/CO          0 non-null      float64
# dtypes: float64(21)
# memory usage: 258.9 KB

# %%
# Estadísticas de SPO2
print(f"\nEstadísticas de SPO2:")
print(datos_de_cirugia['Solar8000/PLETH_SPO2'].describe())
# Out:
# Estadísticas de SPO2:
# count    1518.000000
# mean       99.603426
# std         3.341994
# min        54.000000
# 25%       100.000000
# 50%       100.000000
# 75%       100.000000
# max       100.000000
# Name: Solar8000/PLETH_SPO2, dtype: float64

# %% [markdown]
# ### NOTA
# En este primer proceso de importación traje información de diferentes variables que contenía información de RR (Respiratory Rate), CI(Cardiac Index) y CO (Cardiac Output).
#
# Encontré que la variable `Solar8000/RR`, está casi totlamente vacía. En la tabla de nombres dice que esta variable corresponde a Frecuencia Respiratoria basada en el ECG. Hay otras dos RR: `Solar8000/RR_CO2`(Respiratory rate based on capnography) y `Solar8000/VENT_RR` (Respiratory rate from ventilator). Voy a eliminar la que está vacía y me quedo con las otras dos.
#
# Tambien veo que todas las que observé para CI y CO están completamente vacías, entonces, a pesar de que estos dos datos sería desable tenerlos, debo eliminar las columnas pues ninguna me aporta información.
#
# Voy a volver a importar los datos del caso 0007, con los cambios de las variables para observar de nuevo la información que puedo obetener de este caso

# %%
# El path del archivo es el mismo. Los parámetros son los nuevos, quitando Solar8000/RR y 
# trayendo Solar8000/RR_CO2 y Solar8000/VENT_RR
archivo_cargar = '/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0/vital_files/0007.vital'
parametros = ['Solar8000/RR_CO2','Solar8000/ETCO2','Solar8000/FEO2','Solar8000/FIO2','Solar8000/HR','Solar8000/INCO2','Solar8000/PLETH_HR','Solar8000/PLETH_SPO2','Solar8000/VENT_PIP','Solar8000/VENT_RR','Solar8000/VENT_TV','Primus/MAC']

datos_de_cirugia = vitaldb.VitalFile(archivo_cargar).to_pandas (parametros, interval = 10)

datos_de_cirugia.head()
# Out:
#    Solar8000/RR_CO2  Solar8000/ETCO2  Solar8000/FEO2  Solar8000/FIO2  \
# 0               NaN              1.0            21.0            21.0
# 1               NaN              1.0            21.0            21.0
# 2               NaN              1.0            21.0            21.0
# 3               NaN              1.0            21.0            21.0
# 4               NaN              1.0            21.0            21.0
#
#    Solar8000/HR  Solar8000/INCO2  Solar8000/PLETH_HR  Solar8000/PLETH_SPO2  \
# 0          65.0              1.0                99.0                  61.0
# 1          68.0              1.0                 NaN                   NaN
# 2          67.0              1.0               101.0                  65.0
# 3          67.0              1.0               101.0                  65.0
# 4          67.0              1.0                 NaN                   NaN
#
#    Solar8000/VENT_PIP  Solar8000/VENT_RR  Solar8000/VENT_TV  Primus/MAC
# 0                 NaN                NaN                NaN         0.0
# 1                 NaN                NaN                NaN         0.0
# 2                 NaN                NaN                NaN         0.0
# 3                 NaN                NaN                NaN         0.0
# 4                 NaN                NaN                NaN         0.0

# %% [markdown]
# En las primeras filas veo varias columnas con solo Nan, entonces las voy a observar

# %%
datos_de_cirugia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577 entries, 0 to 1576
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Solar8000/RR_CO2      1395 non-null   float32
#  1   Solar8000/ETCO2       1514 non-null   float32
#  2   Solar8000/FEO2        1514 non-null   float32
#  3   Solar8000/FIO2        1514 non-null   float32
#  4   Solar8000/HR          1467 non-null   float32
#  5   Solar8000/INCO2       1514 non-null   float32
#  6   Solar8000/PLETH_HR    1518 non-null   float32
#  7   Solar8000/PLETH_SPO2  1518 non-null   float32
#  8   Solar8000/VENT_PIP    1359 non-null   float32
#  9   Solar8000/VENT_RR     1397 non-null   float32
#  10  Solar8000/VENT_TV     1390 non-null   float32
#  11  Primus/MAC            1510 non-null   float32
# dtypes: float32(12)
# memory usage: 74.1 KB

# %% [markdown]
# A continuación realizo el tratamiento de datos nulos y registros duplicados

# %%
#Quiero calcular porcentajes valores faltantes
# 2. VALORES FALTANTES
print("\n2. ANÁLISIS DE VALORES FALTANTES")
print("-" * 40)
missing_analysis2 = datos_de_cirugia.isnull().sum()
missing_pct2 = (missing_analysis2 / len(datos_de_cirugia)) * 100
missing_df2 = pd.DataFrame({
        'Missing_Count': missing_analysis2,
        'Missing_Pct': missing_pct2
    }).sort_values('Missing_Pct', ascending=False)
    
print("Columnas con valores faltantes:")
print(missing_df2[missing_df2['Missing_Count'] > 0])
# Out:
# 2. ANÁLISIS DE VALORES FALTANTES
# ----------------------------------------
# Columnas con valores faltantes:
#                       Missing_Count  Missing_Pct
# Solar8000/VENT_PIP              218    13.823716
# Solar8000/VENT_TV               187    11.857958
# Solar8000/RR_CO2                182    11.540900
# Solar8000/VENT_RR               180    11.414077
# Solar8000/HR                    110     6.975269
# Primus/MAC                       67     4.248573
# Solar8000/ETCO2                  63     3.994927
# Solar8000/FEO2                   63     3.994927
# Solar8000/FIO2                   63     3.994927
# Solar8000/INCO2                  63     3.994927
# Solar8000/PLETH_HR               59     3.741281
# Solar8000/PLETH_SPO2             59     3.741281

# %% [markdown]
# Ya no veo un caso tan extremo de valores faltantes, la columna con más nulos tiene un 13.8%. Para no alterar la secuencia temporal de los datos, no debería eliminar registros, sino imputarlos con el método de último valor observado. Pruebo esto con la tabla exploratoria.

# %%
# Realizar la imputación
df_imputado = datos_de_cirugia.ffill()

# Rellenar los valores nulos al inicio de la serie
df_imputado_completo = df_imputado.ffill().bfill()

# Observar el resultado (las primeras filas con valores nulos imputados)
df_imputado_completo.head()
# Out:
#    Solar8000/RR_CO2  Solar8000/ETCO2  Solar8000/FEO2  Solar8000/FIO2  \
# 0               0.0              1.0            21.0            21.0
# 1               0.0              1.0            21.0            21.0
# 2               0.0              1.0            21.0            21.0
# 3               0.0              1.0            21.0            21.0
# 4               0.0              1.0            21.0            21.0
#
#    Solar8000/HR  Solar8000/INCO2  Solar8000/PLETH_HR  Solar8000/PLETH_SPO2  \
# 0          65.0              1.0                99.0                  61.0
# 1          68.0              1.0                99.0                  61.0
# 2          67.0              1.0               101.0                  65.0
# 3          67.0              1.0               101.0                  65.0
# 4          67.0              1.0               101.0                  65.0
#
#    Solar8000/VENT_PIP  Solar8000/VENT_RR  Solar8000/VENT_TV  Primus/MAC
# 0                 4.0                0.0              893.0         0.0
# 1                 4.0                0.0              893.0         0.0
# 2                 4.0                0.0              893.0         0.0
# 3                 4.0                0.0              893.0         0.0
# 4                 4.0                0.0              893.0         0.0

# %%
df_imputado_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577 entries, 0 to 1576
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Solar8000/RR_CO2      1577 non-null   float32
#  1   Solar8000/ETCO2       1577 non-null   float32
#  2   Solar8000/FEO2        1577 non-null   float32
#  3   Solar8000/FIO2        1577 non-null   float32
#  4   Solar8000/HR          1577 non-null   float32
#  5   Solar8000/INCO2       1577 non-null   float32
#  6   Solar8000/PLETH_HR    1577 non-null   float32
#  7   Solar8000/PLETH_SPO2  1577 non-null   float32
#  8   Solar8000/VENT_PIP    1577 non-null   float32
#  9   Solar8000/VENT_RR     1577 non-null   float32
#  10  Solar8000/VENT_TV     1577 non-null   float32
#  11  Primus/MAC            1577 non-null   float32
# dtypes: float32(12)
# memory usage: 74.1 KB

# %% [markdown]
# Veo que funciona. Entonces, teniendo en cuenta las variables definitivas, según los aprendizajes obtenidos del proceso realizado con un sólo archivo, voy a importar todos los archivos correspondientes a los caseid de las cirugías torácicas con VUP

# %% [markdown]
# Ya probada la funcion por medio de la cual se tiene acceso a los datos de los archivos vital, voy a procesar los archivos que corresponden a las 910 cirugías y consolidar esta información en una sola tabla de datos.
#
# ### Pasos a Seguir
#
# 1. Extraer los caseid: Obtengo la lista de los caseid del DataFrame cirugias_VUP_filtrado.
#
# 2. Preparar el bucle: Defino una lista vacía para almacenar los DataFrames de cada cirugía y establezco la ruta base donde se encuentran los archivos .vital.
#
# 3. Iterar y cargar los datos: Dentro de un bucle for, recorro cada caseid. En cada iteración:
#
#     - Formateo el caseid con ceros a la izquierda para que coincida con el nombre del archivo (ej. 7 a '0007').
#
#     - Construyo la ruta completa del archivo .vital.
#
#     - Utilizo la clase vitaldb.VitalFile() y su método .to_pandas() para cargar solo los parámetros que necesito.
#
#     - Añado una nueva columna al DataFrame de esa cirugía con el caseid para poder identificar los datos de cada paciente.
#
#     - Guardo el DataFrame de cada cirugía en la lista definida al inicio.
#
# 4. Combinar los datos: Después de que el bucle termine, uso pd.concat() para unir todos los DataFrames de la lista en una única y gran tabla.

# %%
# 1. Definir la ruta base donde se encuentran los archivos .vital
vital_files_dir = '/Users/anap/Desktop/JAVERIANA/TGrado/DATA&SCRIPTS/vitaldb-1.0.0/vital_files/'

# 2. Extraer los caseid del DataFrame de cirugías filtradas
caseids_a_procesar = cirugias_VUP_filtrado2['caseid'].tolist()

# 3. Definir los parámetros (track names) que necesito
parametros = ['Solar8000/ETCO2','Solar8000/FEO2','Solar8000/FIO2',
              'Solar8000/HR','Solar8000/INCO2','Solar8000/RR_CO2',
              'Solar8000/PLETH_SPO2','Solar8000/PLETH_HR',
              'Solar8000/VENT_PIP','Solar8000/VENT_TV','Solar8000/VENT_RR',
              'Primus/MAC']


# Lista para almacenar los DataFrames de cada cirugía
all_vitals_data = []

# 4. Iterar sobre cada caseid, cargar los datos y guardarlos
for caseid in caseids_a_procesar:
    try:
        # Formatear el caseid a un string de 4 dígitos con ceros
        filename = f"{caseid:04d}.vital"
        file_path = os.path.join(vital_files_dir, filename)

        print(f"Procesando archivo: {filename}")

        # Crear el objeto VitalFile y cargar los datos
        #vital_file = vitaldb.VitalFile(file_path)
        
        # Cargar los datos a un DataFrame, utilizando un intervalo de 10 segundos
        df_temp = vitaldb.VitalFile(file_path).to_pandas(parametros, interval=10)

        # Añadir una columna para identificar el caseid en el DataFrame final
        df_temp['caseid'] = caseid
        
        # Añadir el DataFrame a la lista
        all_vitals_data.append(df_temp)

    except FileNotFoundError:
        print(f"Advertencia: Archivo {filename} no encontrado. Saltando este caso.")
    except Exception as e:
        print(f"Error procesando el archivo {filename}: {e}")

# 5. Concatenar todos los DataFrames en uno solo
if all_vitals_data:
    final_df = pd.concat(all_vitals_data, ignore_index=True)
    print("\nProcesamiento completado. El DataFrame final tiene la siguiente forma:")
    print(final_df.shape)
    final_df.head()
else:
    print("No se pudieron cargar archivos. El DataFrame final está vacío.")
# Out:
# Procesando archivo: 0007.vital
# Procesando archivo: 0013.vital
# Procesando archivo: 0020.vital
# Procesando archivo: 0026.vital
# Procesando archivo: 0028.vital
# Procesando archivo: 0031.vital
# Procesando archivo: 0038.vital
# Procesando archivo: 0044.vital
# Procesando archivo: 0046.vital
# Procesando archivo: 0049.vital
# Procesando archivo: 0067.vital
# Procesando archivo: 0068.vital
# Procesando archivo: 0074.vital
# Procesando archivo: 0075.vital
# Procesando archivo: 0077.vital
# Procesando archivo: 0093.vital
# Procesando archivo: 0103.vital
# Procesando archivo: 0104.vital
# Procesando archivo: 0113.vital
# Procesando archivo: 0126.vital
# Procesando archivo: 0128.vital
# Procesando archivo: 0130.vital
# Procesando archivo: 0132.vital
# Procesando archivo: 0136.vital
# Procesando archivo: 0139.vital
# Procesando archivo: 0145.vital
# Procesando archivo: 0149.vital
# Procesando archivo: 0152.vital
# Procesando archivo: 0153.vital
# Procesando archivo: 0160.vital
# Procesando archivo: 0163.vital
# Procesando archivo: 0167.vital
# Procesando archivo: 0186.vital
# Procesando archivo: 0199.vital
# Procesando archivo: 0200.vital
# Procesando archivo: 0218.vital
# Procesando archivo: 0221.vital
# Procesando archivo: 0241.vital
# Procesando archivo: 0246.vital
# Procesando archivo: 0247.vital
# Procesando archivo: 0258.vital
# Procesando archivo: 0270.vital
# Procesando archivo: 0281.vital
# Procesando archivo: 0293.vital
# Procesando archivo: 0296.vital
# Procesando archivo: 0297.vital
# Procesando archivo: 0316.vital
# Procesando archivo: 0318.vital
# Procesando archivo: 0324.vital
# Procesando archivo: 0332.vital
# Procesando archivo: 0338.vital
# Procesando archivo: 0342.vital
# Procesando archivo: 0347.vital
# Procesando archivo: 0353.vital
# Procesando archivo: 0354.vital
# Procesando archivo: 0358.vital
# Procesando archivo: 0359.vital
# Procesando archivo: 0371.vital
# Procesando archivo: 0380.vital
# Procesando archivo: 0385.vital
# Procesando archivo: 0391.vital
# Procesando archivo: 0402.vital
# Procesando archivo: 0405.vital
# Procesando archivo: 0408.vital
# Procesando archivo: 0413.vital
# Procesando archivo: 0416.vital
# Procesando archivo: 0419.vital
# Procesando archivo: 0435.vital
# Procesando archivo: 0440.vital
# Procesando archivo: 0447.vital
# Procesando archivo: 0460.vital
# Procesando archivo: 0463.vital
# Procesando archivo: 0481.vital
# Procesando archivo: 0484.vital
# Procesando archivo: 0488.vital
# Procesando archivo: 0495.vital
# Procesando archivo: 0531.vital
# Procesando archivo: 0537.vital
# Procesando archivo: 0560.vital
# Procesando archivo: 0561.vital
# Procesando archivo: 0563.vital
# Procesando archivo: 0570.vital
# Procesando archivo: 0579.vital
# Procesando archivo: 0585.vital
# Procesando archivo: 0593.vital
# Procesando archivo: 0599.vital
# Procesando archivo: 0603.vital
# Procesando archivo: 0622.vital
# Procesando archivo: 0624.vital
# Procesando archivo: 0628.vital
# Procesando archivo: 0633.vital
# Procesando archivo: 0634.vital
# Procesando archivo: 0636.vital
# Procesando archivo: 0637.vital
# Procesando archivo: 0657.vital
# Procesando archivo: 0660.vital
# Procesando archivo: 0661.vital
# Procesando archivo: 0667.vital
# Procesando archivo: 0669.vital
# Procesando archivo: 0672.vital
# Procesando archivo: 0679.vital
# Procesando archivo: 0684.vital
# Procesando archivo: 0685.vital
# Procesando archivo: 0699.vital
# Procesando archivo: 0716.vital
# Procesando archivo: 0726.vital
# Procesando archivo: 0727.vital
# Procesando archivo: 0729.vital
# Procesando archivo: 0737.vital
# Procesando archivo: 0744.vital
# Procesando archivo: 0745.vital
# Procesando archivo: 0747.vital
# Procesando archivo: 0749.vital
# Procesando archivo: 0753.vital
# Procesando archivo: 0756.vital
# Procesando archivo: 0757.vital
# Procesando archivo: 0770.vital
# Procesando archivo: 0772.vital
# Procesando archivo: 0773.vital
# Procesando archivo: 0790.vital
# Procesando archivo: 0812.vital
# Procesando archivo: 0816.vital
# Procesando archivo: 0827.vital
# Procesando archivo: 0835.vital
# Procesando archivo: 0841.vital
# Procesando archivo: 0845.vital
# Procesando archivo: 0848.vital
# Procesando archivo: 0855.vital
# Procesando archivo: 0860.vital
# Procesando archivo: 0868.vital
# Procesando archivo: 0881.vital
# Procesando archivo: 0894.vital
# Procesando archivo: 0910.vital
# Procesando archivo: 0922.vital
# Procesando archivo: 0926.vital
# Procesando archivo: 0933.vital
# Procesando archivo: 0940.vital
# Procesando archivo: 0952.vital
# Procesando archivo: 0959.vital
# Procesando archivo: 0967.vital
# Procesando archivo: 0983.vital
# Procesando archivo: 0990.vital
# Procesando archivo: 0993.vital
# Procesando archivo: 0995.vital
# Procesando archivo: 1002.vital
# Procesando archivo: 1004.vital
# Procesando archivo: 1008.vital
# Procesando archivo: 1009.vital
# Procesando archivo: 1016.vital
# Procesando archivo: 1019.vital
# Procesando archivo: 1035.vital
# Procesando archivo: 1041.vital
# Procesando archivo: 1073.vital
# Procesando archivo: 1074.vital
# Procesando archivo: 1077.vital
# Procesando archivo: 1089.vital
# Procesando archivo: 1091.vital
# Procesando archivo: 1094.vital
# Procesando archivo: 1097.vital
# Procesando archivo: 1102.vital
# Procesando archivo: 1103.vital
# Procesando archivo: 1115.vital
# Procesando archivo: 1118.vital
# Procesando archivo: 1133.vital
# Procesando archivo: 1135.vital
# Procesando archivo: 1139.vital
# Procesando archivo: 1144.vital
# Procesando archivo: 1145.vital
# Procesando archivo: 1154.vital
# Procesando archivo: 1183.vital
# Procesando archivo: 1190.vital
# Procesando archivo: 1196.vital
# Procesando archivo: 1202.vital
# Procesando archivo: 1203.vital
# Procesando archivo: 1212.vital
# Procesando archivo: 1221.vital
# Procesando archivo: 1222.vital
# Procesando archivo: 1233.vital
# Procesando archivo: 1234.vital
# Procesando archivo: 1237.vital
# Procesando archivo: 1238.vital
# Procesando archivo: 1240.vital
# Procesando archivo: 1264.vital
# Procesando archivo: 1265.vital
# Procesando archivo: 1268.vital
# Procesando archivo: 1279.vital
# Procesando archivo: 1280.vital
# Procesando archivo: 1294.vital
# Procesando archivo: 1300.vital
# Procesando archivo: 1301.vital
# Procesando archivo: 1319.vital
# Procesando archivo: 1346.vital
# Procesando archivo: 1347.vital
# Procesando archivo: 1375.vital
# Procesando archivo: 1392.vital
# Procesando archivo: 1398.vital
# Procesando archivo: 1404.vital
# Procesando archivo: 1408.vital
# Procesando archivo: 1417.vital
# Procesando archivo: 1432.vital
# Procesando archivo: 1440.vital
# Procesando archivo: 1456.vital
# Procesando archivo: 1471.vital
# Procesando archivo: 1473.vital
# Procesando archivo: 1474.vital
# Procesando archivo: 1484.vital
# Procesando archivo: 1487.vital
# Procesando archivo: 1488.vital
# Procesando archivo: 1490.vital
# Procesando archivo: 1496.vital
# Procesando archivo: 1497.vital
# Procesando archivo: 1500.vital
# Procesando archivo: 1503.vital
# Procesando archivo: 1507.vital
# Procesando archivo: 1511.vital
# Procesando archivo: 1552.vital
# Procesando archivo: 1554.vital
# Procesando archivo: 1555.vital
# Procesando archivo: 1559.vital
# Procesando archivo: 1566.vital
# Procesando archivo: 1575.vital
# Procesando archivo: 1601.vital
# Procesando archivo: 1611.vital
# Procesando archivo: 1612.vital
# Procesando archivo: 1615.vital
# Procesando archivo: 1618.vital
# Procesando archivo: 1658.vital
# Procesando archivo: 1665.vital
# Procesando archivo: 1675.vital
# Procesando archivo: 1676.vital
# Procesando archivo: 1684.vital
# Procesando archivo: 1687.vital
# Procesando archivo: 1690.vital
# Procesando archivo: 1697.vital
# Procesando archivo: 1719.vital
# Procesando archivo: 1733.vital
# Procesando archivo: 1734.vital
# Procesando archivo: 1747.vital
# Procesando archivo: 1748.vital
# Procesando archivo: 1749.vital
# Procesando archivo: 1754.vital
# Procesando archivo: 1756.vital
# Procesando archivo: 1757.vital
# Procesando archivo: 1761.vital
# Procesando archivo: 1765.vital
# Procesando archivo: 1768.vital
# Procesando archivo: 1771.vital
# Procesando archivo: 1773.vital
# Procesando archivo: 1784.vital
# Procesando archivo: 1806.vital
# Procesando archivo: 1810.vital
# Procesando archivo: 1814.vital
# Procesando archivo: 1823.vital
# Procesando archivo: 1825.vital
# Procesando archivo: 1836.vital
# Procesando archivo: 1844.vital
# Procesando archivo: 1846.vital
# Procesando archivo: 1849.vital
# Procesando archivo: 1866.vital
# Procesando archivo: 1875.vital
# Procesando archivo: 1876.vital
# Procesando archivo: 1882.vital
# Procesando archivo: 1898.vital
# Procesando archivo: 1913.vital
# Procesando archivo: 1918.vital
# Procesando archivo: 1920.vital
# Procesando archivo: 1922.vital
# Procesando archivo: 1925.vital
# Procesando archivo: 1939.vital
# Procesando archivo: 1942.vital
# Procesando archivo: 1943.vital
# Procesando archivo: 1947.vital
# Procesando archivo: 1956.vital
# Procesando archivo: 1957.vital
# Procesando archivo: 1969.vital
# Procesando archivo: 1985.vital
# Procesando archivo: 1999.vital
# Procesando archivo: 2004.vital
# Procesando archivo: 2009.vital
# Procesando archivo: 2015.vital
# Procesando archivo: 2029.vital
# Procesando archivo: 2039.vital
# Procesando archivo: 2046.vital
# Procesando archivo: 2049.vital
# Procesando archivo: 2057.vital
# Procesando archivo: 2060.vital
# Procesando archivo: 2074.vital
# Procesando archivo: 2075.vital
# Procesando archivo: 2083.vital
# Procesando archivo: 2085.vital
# Procesando archivo: 2088.vital
# Procesando archivo: 2098.vital
# Procesando archivo: 2111.vital
# Procesando archivo: 2118.vital
# Procesando archivo: 2120.vital
# Procesando archivo: 2135.vital
# Procesando archivo: 2142.vital
# Procesando archivo: 2150.vital
# Procesando archivo: 2158.vital
# Procesando archivo: 2162.vital
# Procesando archivo: 2163.vital
# Procesando archivo: 2165.vital
# Procesando archivo: 2170.vital
# Procesando archivo: 2175.vital
# Procesando archivo: 2205.vital
# Procesando archivo: 2213.vital
# Procesando archivo: 2219.vital
# Procesando archivo: 2221.vital
# Procesando archivo: 2222.vital
# Procesando archivo: 2244.vital
# Procesando archivo: 2249.vital
# Procesando archivo: 2276.vital
# Procesando archivo: 2280.vital
# Procesando archivo: 2281.vital
# Procesando archivo: 2283.vital
# Procesando archivo: 2284.vital
# Procesando archivo: 2305.vital
# Procesando archivo: 2309.vital
# Procesando archivo: 2310.vital
# Procesando archivo: 2311.vital
# Procesando archivo: 2315.vital
# Procesando archivo: 2317.vital
# Procesando archivo: 2335.vital
# Procesando archivo: 2339.vital
# Procesando archivo: 2344.vital
# Procesando archivo: 2349.vital
# Procesando archivo: 2357.vital
# Procesando archivo: 2377.vital
# Procesando archivo: 2379.vital
# Procesando archivo: 2380.vital
# Procesando archivo: 2381.vital
# Procesando archivo: 2392.vital
# Procesando archivo: 2393.vital
# Procesando archivo: 2409.vital
# Procesando archivo: 2412.vital
# Procesando archivo: 2413.vital
# Procesando archivo: 2417.vital
# Procesando archivo: 2419.vital
# Procesando archivo: 2434.vital
# Procesando archivo: 2435.vital
# Procesando archivo: 2436.vital
# Procesando archivo: 2438.vital
# Procesando archivo: 2442.vital
# Procesando archivo: 2444.vital
# Procesando archivo: 2446.vital
# Procesando archivo: 2450.vital
# Procesando archivo: 2452.vital
# Procesando archivo: 2457.vital
# Procesando archivo: 2460.vital
# Procesando archivo: 2466.vital
# Procesando archivo: 2469.vital
# Procesando archivo: 2479.vital
# Procesando archivo: 2481.vital
# Procesando archivo: 2482.vital
# Procesando archivo: 2489.vital
# Procesando archivo: 2497.vital
# Procesando archivo: 2498.vital
# Procesando archivo: 2500.vital
# Procesando archivo: 2503.vital
# Procesando archivo: 2509.vital
# Procesando archivo: 2528.vital
# Procesando archivo: 2533.vital
# Procesando archivo: 2539.vital
# Procesando archivo: 2562.vital
# Procesando archivo: 2569.vital
# Procesando archivo: 2572.vital
# Procesando archivo: 2576.vital
# Procesando archivo: 2589.vital
# Procesando archivo: 2608.vital
# Procesando archivo: 2612.vital
# Procesando archivo: 2616.vital
# Procesando archivo: 2632.vital
# Procesando archivo: 2633.vital
# Procesando archivo: 2639.vital
# Procesando archivo: 2640.vital
# Procesando archivo: 2641.vital
# Procesando archivo: 2644.vital
# Procesando archivo: 2646.vital
# Procesando archivo: 2654.vital
# Procesando archivo: 2655.vital
# Procesando archivo: 2657.vital
# Procesando archivo: 2673.vital
# Procesando archivo: 2676.vital
# Procesando archivo: 2680.vital
# Procesando archivo: 2690.vital
# Procesando archivo: 2697.vital
# Procesando archivo: 2698.vital
# Procesando archivo: 2713.vital
# Procesando archivo: 2717.vital
# Procesando archivo: 2720.vital
# Procesando archivo: 2721.vital
# Procesando archivo: 2732.vital
# Procesando archivo: 2736.vital
# Procesando archivo: 2740.vital
# Procesando archivo: 2744.vital
# Procesando archivo: 2750.vital
# Procesando archivo: 2760.vital
# Procesando archivo: 2762.vital
# Procesando archivo: 2763.vital
# Procesando archivo: 2771.vital
# Procesando archivo: 2774.vital
# Procesando archivo: 2777.vital
# Procesando archivo: 2799.vital
# Procesando archivo: 2803.vital
# Procesando archivo: 2806.vital
# Procesando archivo: 2809.vital
# Procesando archivo: 2823.vital
# Procesando archivo: 2827.vital
# Procesando archivo: 2830.vital
# Procesando archivo: 2836.vital
# Procesando archivo: 2845.vital
# Procesando archivo: 2848.vital
# Procesando archivo: 2859.vital
# Procesando archivo: 2861.vital
# Procesando archivo: 2864.vital
# Procesando archivo: 2871.vital
# Procesando archivo: 2889.vital
# Procesando archivo: 2905.vital
# Procesando archivo: 2909.vital
# Procesando archivo: 2911.vital
# Procesando archivo: 2919.vital
# Procesando archivo: 2924.vital
# Procesando archivo: 2927.vital
# Procesando archivo: 2933.vital
# Procesando archivo: 2944.vital
# Procesando archivo: 2955.vital
# Procesando archivo: 2956.vital
# Procesando archivo: 2975.vital
# Procesando archivo: 2980.vital
# Procesando archivo: 2981.vital
# Procesando archivo: 2987.vital
# Procesando archivo: 2992.vital
# Procesando archivo: 3003.vital
# Procesando archivo: 3020.vital
# Procesando archivo: 3027.vital
# Procesando archivo: 3030.vital
# Procesando archivo: 3034.vital
# Procesando archivo: 3042.vital
# Procesando archivo: 3046.vital
# Procesando archivo: 3047.vital
# Procesando archivo: 3060.vital
# Procesando archivo: 3069.vital
# Procesando archivo: 3070.vital
# Procesando archivo: 3075.vital
# Procesando archivo: 3076.vital
# Procesando archivo: 3088.vital
# Procesando archivo: 3091.vital
# Procesando archivo: 3092.vital
# Procesando archivo: 3095.vital
# Procesando archivo: 3096.vital
# Procesando archivo: 3112.vital
# Procesando archivo: 3114.vital
# Procesando archivo: 3118.vital
# Procesando archivo: 3122.vital
# Procesando archivo: 3135.vital
# Procesando archivo: 3141.vital
# Procesando archivo: 3153.vital
# Procesando archivo: 3169.vital
# Procesando archivo: 3172.vital
# Procesando archivo: 3175.vital
# Procesando archivo: 3177.vital
# Procesando archivo: 3184.vital
# Procesando archivo: 3198.vital
# Procesando archivo: 3200.vital
# Procesando archivo: 3204.vital
# Procesando archivo: 3205.vital
# Procesando archivo: 3211.vital
# Procesando archivo: 3214.vital
# Procesando archivo: 3221.vital
# Procesando archivo: 3231.vital
# Procesando archivo: 3239.vital
# Procesando archivo: 3240.vital
# Procesando archivo: 3255.vital
# Procesando archivo: 3256.vital
# Procesando archivo: 3273.vital
# Procesando archivo: 3275.vital
# Procesando archivo: 3279.vital
# Procesando archivo: 3299.vital
# Procesando archivo: 3304.vital
# Procesando archivo: 3317.vital
# Procesando archivo: 3329.vital
# Procesando archivo: 3331.vital
# Procesando archivo: 3332.vital
# Procesando archivo: 3338.vital
# Procesando archivo: 3340.vital
# Procesando archivo: 3344.vital
# Procesando archivo: 3352.vital
# Procesando archivo: 3366.vital
# Procesando archivo: 3367.vital
# Procesando archivo: 3369.vital
# Procesando archivo: 3377.vital
# Procesando archivo: 3391.vital
# Procesando archivo: 3394.vital
# Procesando archivo: 3399.vital
# Procesando archivo: 3412.vital
# Procesando archivo: 3414.vital
# Procesando archivo: 3422.vital
# Procesando archivo: 3426.vital
# Procesando archivo: 3434.vital
# Procesando archivo: 3463.vital
# Procesando archivo: 3470.vital
# Procesando archivo: 3472.vital
# Procesando archivo: 3479.vital
# Procesando archivo: 3490.vital
# Procesando archivo: 3498.vital
# Procesando archivo: 3499.vital
# Procesando archivo: 3500.vital
# Procesando archivo: 3514.vital
# Procesando archivo: 3538.vital
# Procesando archivo: 3544.vital
# Procesando archivo: 3558.vital
# Procesando archivo: 3560.vital
# Procesando archivo: 3563.vital
# Procesando archivo: 3564.vital
# Procesando archivo: 3570.vital
# Procesando archivo: 3582.vital
# Procesando archivo: 3596.vital
# Procesando archivo: 3600.vital
# Procesando archivo: 3603.vital
# Procesando archivo: 3608.vital
# Procesando archivo: 3625.vital
# Procesando archivo: 3629.vital
# Procesando archivo: 3637.vital
# Procesando archivo: 3646.vital
# Procesando archivo: 3680.vital
# Procesando archivo: 3688.vital
# Procesando archivo: 3690.vital
# Procesando archivo: 3691.vital
# Procesando archivo: 3692.vital
# Procesando archivo: 3696.vital
# Procesando archivo: 3709.vital
# Procesando archivo: 3712.vital
# Procesando archivo: 3729.vital
# Procesando archivo: 3730.vital
# Procesando archivo: 3740.vital
# Procesando archivo: 3743.vital
# Procesando archivo: 3748.vital
# Procesando archivo: 3784.vital
# Procesando archivo: 3802.vital
# Procesando archivo: 3803.vital
# Procesando archivo: 3810.vital
# Procesando archivo: 3812.vital
# Procesando archivo: 3816.vital
# Procesando archivo: 3821.vital
# Procesando archivo: 3825.vital
# Procesando archivo: 3837.vital
# Procesando archivo: 3855.vital
# Procesando archivo: 3859.vital
# Procesando archivo: 3865.vital
# Procesando archivo: 3868.vital
# Procesando archivo: 3877.vital
# Procesando archivo: 3881.vital
# Procesando archivo: 3885.vital
# Procesando archivo: 3897.vital
# Procesando archivo: 3910.vital
# Procesando archivo: 3915.vital
# Procesando archivo: 3922.vital
# Procesando archivo: 3928.vital
# Procesando archivo: 3935.vital
# Procesando archivo: 3958.vital
# Procesando archivo: 3962.vital
# Procesando archivo: 3971.vital
# Procesando archivo: 3976.vital
# Procesando archivo: 3978.vital
# Procesando archivo: 3986.vital
# Procesando archivo: 3988.vital
# Procesando archivo: 3990.vital
# Procesando archivo: 4004.vital
# Procesando archivo: 4016.vital
# Procesando archivo: 4017.vital
# Procesando archivo: 4020.vital
# Procesando archivo: 4030.vital
# Procesando archivo: 4032.vital
# Procesando archivo: 4037.vital
# Procesando archivo: 4048.vital
# Procesando archivo: 4058.vital
# Procesando archivo: 4062.vital
# Procesando archivo: 4069.vital
# Procesando archivo: 4073.vital
# Procesando archivo: 4077.vital
# Procesando archivo: 4083.vital
# Procesando archivo: 4101.vital
# Procesando archivo: 4107.vital
# Procesando archivo: 4122.vital
# Procesando archivo: 4127.vital
# Procesando archivo: 4128.vital
# Procesando archivo: 4142.vital
# Procesando archivo: 4143.vital
# Procesando archivo: 4146.vital
# Procesando archivo: 4148.vital
# Procesando archivo: 4149.vital
# Procesando archivo: 4163.vital
# Procesando archivo: 4169.vital
# Procesando archivo: 4177.vital
# Procesando archivo: 4181.vital
# Procesando archivo: 4198.vital
# Procesando archivo: 4202.vital
# Procesando archivo: 4210.vital
# Procesando archivo: 4212.vital
# Procesando archivo: 4222.vital
# Procesando archivo: 4227.vital
# Procesando archivo: 4240.vital
# Procesando archivo: 4241.vital
# Procesando archivo: 4245.vital
# Procesando archivo: 4261.vital
# Procesando archivo: 4268.vital
# Procesando archivo: 4277.vital
# Procesando archivo: 4287.vital
# Procesando archivo: 4292.vital
# Procesando archivo: 4294.vital
# Procesando archivo: 4296.vital
# Procesando archivo: 4306.vital
# Procesando archivo: 4317.vital
# Procesando archivo: 4339.vital
# Procesando archivo: 4350.vital
# Procesando archivo: 4352.vital
# Procesando archivo: 4364.vital
# Procesando archivo: 4377.vital
# Procesando archivo: 4380.vital
# Procesando archivo: 4385.vital
# Procesando archivo: 4387.vital
# Procesando archivo: 4390.vital
# Procesando archivo: 4396.vital
# Procesando archivo: 4400.vital
# Procesando archivo: 4404.vital
# Procesando archivo: 4406.vital
# Procesando archivo: 4409.vital
# Procesando archivo: 4411.vital
# Procesando archivo: 4426.vital
# Procesando archivo: 4435.vital
# Procesando archivo: 4453.vital
# Procesando archivo: 4457.vital
# Procesando archivo: 4464.vital
# Procesando archivo: 4472.vital
# Procesando archivo: 4485.vital
# Procesando archivo: 4497.vital
# Procesando archivo: 4501.vital
# Procesando archivo: 4502.vital
# Procesando archivo: 4503.vital
# Procesando archivo: 4527.vital
# Procesando archivo: 4541.vital
# Procesando archivo: 4546.vital
# Procesando archivo: 4550.vital
# Procesando archivo: 4561.vital
# Procesando archivo: 4577.vital
# Procesando archivo: 4579.vital
# Procesando archivo: 4584.vital
# Procesando archivo: 4589.vital
# Procesando archivo: 4597.vital
# Procesando archivo: 4616.vital
# Procesando archivo: 4618.vital
# Procesando archivo: 4620.vital
# Procesando archivo: 4624.vital
# Procesando archivo: 4631.vital
# Procesando archivo: 4639.vital
# Procesando archivo: 4640.vital
# Procesando archivo: 4654.vital
# Procesando archivo: 4660.vital
# Procesando archivo: 4662.vital
# Procesando archivo: 4678.vital
# Procesando archivo: 4695.vital
# Procesando archivo: 4702.vital
# Procesando archivo: 4705.vital
# Procesando archivo: 4713.vital
# Procesando archivo: 4716.vital
# Procesando archivo: 4717.vital
# Procesando archivo: 4726.vital
# Procesando archivo: 4727.vital
# Procesando archivo: 4730.vital
# Procesando archivo: 4741.vital
# Procesando archivo: 4755.vital
# Procesando archivo: 4757.vital
# Procesando archivo: 4763.vital
# Procesando archivo: 4765.vital
# Procesando archivo: 4767.vital
# Procesando archivo: 4768.vital
# Procesando archivo: 4769.vital
# Procesando archivo: 4784.vital
# Procesando archivo: 4786.vital
# Procesando archivo: 4788.vital
# Procesando archivo: 4789.vital
# Procesando archivo: 4791.vital
# Procesando archivo: 4794.vital
# Procesando archivo: 4803.vital
# Procesando archivo: 4830.vital
# Procesando archivo: 4831.vital
# Procesando archivo: 4834.vital
# Procesando archivo: 4836.vital
# Procesando archivo: 4859.vital
# Procesando archivo: 4860.vital
# Procesando archivo: 4879.vital
# Procesando archivo: 4886.vital
# Procesando archivo: 4901.vital
# Procesando archivo: 4904.vital
# Procesando archivo: 4913.vital
# Procesando archivo: 4915.vital
# Procesando archivo: 4935.vital
# Procesando archivo: 4936.vital
# Procesando archivo: 4938.vital
# Procesando archivo: 4949.vital
# Procesando archivo: 4954.vital
# Procesando archivo: 4965.vital
# Procesando archivo: 4971.vital
# Procesando archivo: 4973.vital
# Procesando archivo: 4976.vital
# Procesando archivo: 4991.vital
# Procesando archivo: 4992.vital
# Procesando archivo: 4998.vital
# Procesando archivo: 5008.vital
# Procesando archivo: 5014.vital
# Procesando archivo: 5029.vital
# Procesando archivo: 5031.vital
# Procesando archivo: 5061.vital
# Procesando archivo: 5067.vital
# Procesando archivo: 5070.vital
# Procesando archivo: 5075.vital
# Procesando archivo: 5077.vital
# Procesando archivo: 5079.vital
# Procesando archivo: 5093.vital
# Procesando archivo: 5104.vital
# Procesando archivo: 5107.vital
# Procesando archivo: 5111.vital
# Procesando archivo: 5112.vital
# Procesando archivo: 5122.vital
# Procesando archivo: 5143.vital
# Procesando archivo: 5145.vital
# Procesando archivo: 5155.vital
# Procesando archivo: 5156.vital
# Procesando archivo: 5163.vital
# Procesando archivo: 5164.vital
# Procesando archivo: 5174.vital
# Procesando archivo: 5183.vital
# Procesando archivo: 5192.vital
# Procesando archivo: 5194.vital
# Procesando archivo: 5195.vital
# Procesando archivo: 5202.vital
# Procesando archivo: 5204.vital
# Procesando archivo: 5209.vital
# Procesando archivo: 5213.vital
# Procesando archivo: 5218.vital
# Procesando archivo: 5223.vital
# Procesando archivo: 5224.vital
# Procesando archivo: 5234.vital
# Procesando archivo: 5262.vital
# Procesando archivo: 5265.vital
# Procesando archivo: 5266.vital
# Procesando archivo: 5267.vital
# Procesando archivo: 5274.vital
# Procesando archivo: 5277.vital
# Procesando archivo: 5283.vital
# Procesando archivo: 5285.vital
# Procesando archivo: 5292.vital
# Procesando archivo: 5298.vital
# Procesando archivo: 5302.vital
# Procesando archivo: 5311.vital
# Procesando archivo: 5322.vital
# Procesando archivo: 5323.vital
# Procesando archivo: 5327.vital
# Procesando archivo: 5344.vital
# Procesando archivo: 5348.vital
# Procesando archivo: 5352.vital
# Procesando archivo: 5356.vital
# Procesando archivo: 5359.vital
# Procesando archivo: 5363.vital
# Procesando archivo: 5364.vital
# Procesando archivo: 5366.vital
# Procesando archivo: 5368.vital
# Procesando archivo: 5384.vital
# Procesando archivo: 5388.vital
# Procesando archivo: 5390.vital
# Procesando archivo: 5393.vital
# Procesando archivo: 5399.vital
# Procesando archivo: 5410.vital
# Procesando archivo: 5415.vital
# Procesando archivo: 5421.vital
# Procesando archivo: 5434.vital
# Procesando archivo: 5436.vital
# Procesando archivo: 5449.vital
# Procesando archivo: 5460.vital
# Procesando archivo: 5462.vital
# Procesando archivo: 5464.vital
# Procesando archivo: 5470.vital
# Procesando archivo: 5475.vital
# Procesando archivo: 5478.vital
# Procesando archivo: 5484.vital
# Procesando archivo: 5487.vital
# Procesando archivo: 5490.vital
# Procesando archivo: 5499.vital
# Procesando archivo: 5502.vital
# Procesando archivo: 5534.vital
# Procesando archivo: 5536.vital
# Procesando archivo: 5541.vital
# Procesando archivo: 5548.vital
# Procesando archivo: 5562.vital
# Procesando archivo: 5565.vital
# Procesando archivo: 5571.vital
# Procesando archivo: 5572.vital
# Procesando archivo: 5573.vital
# Procesando archivo: 5589.vital
# Procesando archivo: 5594.vital
# Procesando archivo: 5599.vital
# Procesando archivo: 5608.vital
# Procesando archivo: 5610.vital
# Procesando archivo: 5617.vital
# Procesando archivo: 5629.vital
# Procesando archivo: 5635.vital
# Procesando archivo: 5648.vital
# Procesando archivo: 5662.vital
# Procesando archivo: 5664.vital
# Procesando archivo: 5680.vital
# Procesando archivo: 5685.vital
# Procesando archivo: 5692.vital
# Procesando archivo: 5718.vital
# Procesando archivo: 5727.vital
# Procesando archivo: 5728.vital
# Procesando archivo: 5732.vital
# Procesando archivo: 5765.vital
# Procesando archivo: 5774.vital
# Procesando archivo: 5778.vital
# Procesando archivo: 5780.vital
# Procesando archivo: 5781.vital
# Procesando archivo: 5784.vital
# Procesando archivo: 5793.vital
# Procesando archivo: 5799.vital
# Procesando archivo: 5800.vital
# Procesando archivo: 5808.vital
# Procesando archivo: 5810.vital
# Procesando archivo: 5811.vital
# Procesando archivo: 5817.vital
# Procesando archivo: 5818.vital
# Procesando archivo: 5822.vital
# Procesando archivo: 5825.vital
# Procesando archivo: 5827.vital
# Procesando archivo: 5831.vital
# Procesando archivo: 5832.vital
# Procesando archivo: 5835.vital
# Procesando archivo: 5848.vital
# Procesando archivo: 5851.vital
# Procesando archivo: 5861.vital
# Procesando archivo: 5862.vital
# Procesando archivo: 5882.vital
# Procesando archivo: 5887.vital
# Procesando archivo: 5889.vital
# Procesando archivo: 5890.vital
# Procesando archivo: 5916.vital
# Procesando archivo: 5933.vital
# Procesando archivo: 5934.vital
# Procesando archivo: 5938.vital
# Procesando archivo: 5940.vital
# Procesando archivo: 5942.vital
# Procesando archivo: 5948.vital
# Procesando archivo: 5951.vital
# Procesando archivo: 5958.vital
# Procesando archivo: 5959.vital
# Procesando archivo: 5965.vital
# Procesando archivo: 5966.vital
# Procesando archivo: 5970.vital
# Procesando archivo: 5974.vital
# Procesando archivo: 6006.vital
# Procesando archivo: 6013.vital
# Procesando archivo: 6018.vital
# Procesando archivo: 6041.vital
# Procesando archivo: 6055.vital
# Procesando archivo: 6057.vital
# Procesando archivo: 6060.vital
# Procesando archivo: 6070.vital
# Procesando archivo: 6071.vital
# Procesando archivo: 6084.vital
# Procesando archivo: 6087.vital
# Procesando archivo: 6088.vital
# Procesando archivo: 6097.vital
# Procesando archivo: 6124.vital
# Procesando archivo: 6128.vital
# Procesando archivo: 6131.vital
# Procesando archivo: 6132.vital
# Procesando archivo: 6135.vital
# Procesando archivo: 6136.vital
# Procesando archivo: 6153.vital
# Procesando archivo: 6154.vital
# Procesando archivo: 6165.vital
# Procesando archivo: 6168.vital
# Procesando archivo: 6174.vital
# Procesando archivo: 6192.vital
# Procesando archivo: 6195.vital
# Procesando archivo: 6199.vital
# Procesando archivo: 6200.vital
# Procesando archivo: 6204.vital
# Procesando archivo: 6205.vital
# Procesando archivo: 6208.vital
# Procesando archivo: 6235.vital
# Procesando archivo: 6237.vital
# Procesando archivo: 6238.vital
# Procesando archivo: 6239.vital
# Procesando archivo: 6250.vital
# Procesando archivo: 6260.vital
# Procesando archivo: 6267.vital
# Procesando archivo: 6268.vital
# Procesando archivo: 6281.vital
# Procesando archivo: 6285.vital
# Procesando archivo: 6291.vital
# Procesando archivo: 6295.vital
# Procesando archivo: 6298.vital
# Procesando archivo: 6302.vital
# Procesando archivo: 6306.vital
# Procesando archivo: 6307.vital
# Procesando archivo: 6309.vital
# Procesando archivo: 6311.vital
# Procesando archivo: 6366.vital
# Procesando archivo: 6370.vital
# Procesando archivo: 6376.vital
#
# Procesamiento completado. El DataFrame final tiene la siguiente forma:
# (1075328, 13)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1075328 entries, 0 to 1075327
# Data columns (total 13 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Solar8000/ETCO2       1007385 non-null  float64
#  1   Solar8000/FEO2        1007254 non-null  float64
#  2   Solar8000/FIO2        1007351 non-null  float64
#  3   Solar8000/HR          990694 non-null   float64
#  4   Solar8000/INCO2       1007477 non-null  float64
#  5   Solar8000/RR_CO2      960686 non-null   float64
#  6   Solar8000/PLETH_SPO2  1015257 non-null  float64
#  7   Solar8000/PLETH_HR    1014730 non-null  float64
#  8   Solar8000/VENT_PIP    919531 non-null   float64
#  9   Solar8000/VENT_TV     937441 non-null   float64
#  10  Solar8000/VENT_RR     942599 non-null   float64
#  11  Primus/MAC            1009964 non-null  float64
#  12  caseid                1075328 non-null  int64
# dtypes: float64(12), int64(1)
# memory usage: 106.7 MB

# %%
#Quiero consultar valores faltantes
# 2. VALORES FALTANTES
print("\n2. ANÁLISIS DE VALORES FALTANTES")
print("-" * 40)
missing_analysis3 = final_df.isnull().sum()
missing_pct3 = (missing_analysis3 / len(final_df)) * 100
missing_df3 = pd.DataFrame({
        'Missing_Count': missing_analysis3,
        'Missing_Pct': missing_pct3
    }).sort_values('Missing_Pct', ascending=False)
    
print("Columnas con valores faltantes:")
print(missing_df3[missing_df3['Missing_Count'] > 0])
# Out:
# 2. ANÁLISIS DE VALORES FALTANTES
# ----------------------------------------
# Columnas con valores faltantes:
#                       Missing_Count  Missing_Pct
# Solar8000/VENT_PIP           155797    14.488324
# Solar8000/VENT_TV            137887    12.822785
# Solar8000/VENT_RR            132729    12.343118
# Solar8000/RR_CO2             114642    10.661119
# Solar8000/HR                  84634     7.870529
# Solar8000/FEO2                68074     6.330534
# Solar8000/FIO2                67977     6.321513
# Solar8000/ETCO2               67943     6.318351
# Solar8000/INCO2               67851     6.309796
# Primus/MAC                    65364     6.078517
# Solar8000/PLETH_HR            60598     5.635304
# Solar8000/PLETH_SPO2          60071     5.586296

# %% [markdown]
# Los porcentajes de valores nulos no son tal altos. Decido que la forma de abordarlos no es eliminando registros, pues podría perder registros consecutivos y alterar la veracidad de mis datos. Voy a  imputarlos con el método de último valor observado. que ya probé con la tabla exploratoria.
#
# Primero observo estadísticas, antes de la imputación, para comparar luego de imputar datos nulos

# %%
#Observo estadísticas antes de la imputación para comparar luego de imputar datos nulos
# Estadísticas de ETCO2
print(f"\nEstadísticas de ETCO2:")
print(final_df['Solar8000/ETCO2'].describe())

# Estadísticas de FEO2
print(f"\nEstadísticas de FEO2:")
print(final_df['Solar8000/FEO2'].describe())

# Estadísticas de FIO2
print(f"\nEstadísticas de FIO2:")
print(final_df['Solar8000/FIO2'].describe())

# Estadísticas de HR
print(f"\nEstadísticas de HR:")
print(final_df['Solar8000/HR'].describe())

# Estadísticas de INCO2
print(f"\nEstadísticas de INCO2:")
print(final_df['Solar8000/INCO2'].describe())

# Estadísticas de RR_CO2
print(f"\nEstadísticas de RR_CO2:")
print(final_df['Solar8000/RR_CO2'].describe())

# Estadísticas de VENT RR
print(f"\nEstadísticas de VENT RR:")
print(final_df['Solar8000/VENT_RR'].describe())

# Estadísticas de PLETH_SPO2
print(f"\nEstadísticas de PLETH_SPO2:")
print(final_df['Solar8000/PLETH_SPO2'].describe())

# Estadísticas de PLETH_HR
print(f"\nEstadísticas de PLETH_HR:")
print(final_df['Solar8000/PLETH_HR'].describe())

# Estadísticas de VENT PIP
print(f"\nEstadísticas de VENT PIP:")
print(final_df['Solar8000/VENT_PIP'].describe())

# Estadísticas de VENT TV
print(f"\nEstadísticas de VENT TV:")
print(final_df['Solar8000/VENT_TV'].describe())

# Estadísticas de MAC
print(f"\nEstadísticas de MAC:")
print(final_df['Primus/MAC'].describe())

# Estadísticas de casos
print(f"\nEstadísticas de casos:")
print(final_df['caseid'].describe())
# Out:
# Estadísticas de ETCO2:
# count    1.007385e+06
# mean     3.307931e+01
# std      8.701448e+00
# min      0.000000e+00
# 25%      3.200000e+01
# 50%      3.500000e+01
# 75%      3.700000e+01
# max      8.700000e+01
# Name: Solar8000/ETCO2, dtype: float64
#
# Estadísticas de FEO2:
# count    1.007254e+06
# mean     6.602261e+01
# std      1.874778e+01
# min      1.100000e+01
# 25%      5.100000e+01
# 50%      7.000000e+01
# 75%      8.400000e+01
# max      1.000000e+02
# Name: Solar8000/FEO2, dtype: float64
#
# Estadísticas de FIO2:
# count    1.007351e+06
# mean     7.178781e+01
# std      1.893795e+01
# min      1.200000e+01
# 25%      5.600000e+01
# 50%      7.500000e+01
# 75%      9.100000e+01
# max      1.000000e+02
# Name: Solar8000/FIO2, dtype: float64
#
# Estadísticas de HR:
# count    990694.000000
# mean         72.209031
# std          16.865262
# min           0.000000
# 25%          61.000000
# 50%          71.000000
# 75%          82.000000
# max         259.000000
# Name: Solar8000/HR, dtype: float64
#
# Estadísticas de INCO2:
# count    1.007477e+06
# mean     8.289221e-01
# std      1.312496e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      6.200000e+01
# Name: Solar8000/INCO2, dtype: float64
#
# Estadísticas de RR_CO2:
# count    960686.000000
# mean         14.284910
# std           3.316499
# min           0.000000
# 25%          12.000000
# 50%          14.000000
# 75%          16.000000
# max          70.000000
# Name: Solar8000/RR_CO2, dtype: float64
#
# Estadísticas de VENT RR:
# count    942599.000000
# mean         14.319901
# std           3.465130
# min           0.000000
# 25%          12.000000
# 50%          14.000000
# 75%          16.000000
# max          70.000000
# Name: Solar8000/VENT_RR, dtype: float64
#
# Estadísticas de PLETH_SPO2:
# count    1.015257e+06
# mean     9.924909e+01
# std      2.514190e+00
# min      2.700000e+01
# 25%      1.000000e+02
# 50%      1.000000e+02
# 75%      1.000000e+02
# max      1.000000e+02
# Name: Solar8000/PLETH_SPO2, dtype: float64
#
# Estadísticas de PLETH_HR:
# count    1.014730e+06
# mean     7.242402e+01
# std      1.650966e+01
# min      4.000000e+00
# 25%      6.200000e+01
# 50%      7.000000e+01
# 75%      8.100000e+01
# max      3.000000e+02
# Name: Solar8000/PLETH_HR, dtype: float64
#
# Estadísticas de VENT PIP:
# count    919531.000000
# mean         20.687322
# std           5.365097
# min          -4.000000
# 25%          17.000000
# 50%          20.000000
# 75%          23.000000
# max          80.000000
# Name: Solar8000/VENT_PIP, dtype: float64
#
# Estadísticas de VENT TV:
# count    937441.000000
# mean        341.120258
# std         107.704401
# min          10.000000
# 25%         289.000000
# 50%         337.000000
# 75%         388.000000
# max        2960.000000
# Name: Solar8000/VENT_TV, dtype: float64
#
# Estadísticas de MAC:
# count    1.009964e+06
# mean     1.823520e-02
# std      1.177527e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.100000e+00
# Name: Primus/MAC, dtype: float64
#
# Estadísticas de casos:
# count    1.075328e+06
# mean     3.204699e+03
# std      1.892280e+03
# min      7.000000e+00
# 25%      1.555000e+03
# 50%      3.205000e+03
# 75%      4.915000e+03
# max      6.376000e+03
# Name: caseid, dtype: float64

# %%
# IMPUTACIÓN DE DATOS NULOS
# Puedo especificar un límite para la imputación para evitar que se propague por huecos de 
# tiempo muy largos.elijo llenar un máximo de 5 valores nulos consecutiv
df_imputado = final_df.ffill(limit=5)

# Rellenar los valores nulos al inicio de la serie
df_imputado_completo = df_imputado.ffill().bfill()

df_imputado_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1075328 entries, 0 to 1075327
# Data columns (total 13 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Solar8000/ETCO2       1075328 non-null  float64
#  1   Solar8000/FEO2        1075328 non-null  float64
#  2   Solar8000/FIO2        1075328 non-null  float64
#  3   Solar8000/HR          1075328 non-null  float64
#  4   Solar8000/INCO2       1075328 non-null  float64
#  5   Solar8000/RR_CO2      1075328 non-null  float64
#  6   Solar8000/PLETH_SPO2  1075328 non-null  float64
#  7   Solar8000/PLETH_HR    1075328 non-null  float64
#  8   Solar8000/VENT_PIP    1075328 non-null  float64
#  9   Solar8000/VENT_TV     1075328 non-null  float64
#  10  Solar8000/VENT_RR     1075328 non-null  float64
#  11  Primus/MAC            1075328 non-null  float64
#  12  caseid                1075328 non-null  int64
# dtypes: float64(12), int64(1)
# memory usage: 106.7 MB

# %% [markdown]
# Puedo observar que la totalidad de las columnas quedaron sin datos nulos.

# %%
#Observo estadísticas después de la imputación para comparar luego de imputar datos nulos
# Estadísticas de ETCO2
print(f"\nEstadísticas de ETCO2:")
print(df_imputado_completo['Solar8000/ETCO2'].describe())

# Estadísticas de FEO2
print(f"\nEstadísticas de FEO2:")
print(df_imputado_completo['Solar8000/FEO2'].describe())

# Estadísticas de FIO2
print(f"\nEstadísticas de FIO2:")
print(df_imputado_completo['Solar8000/FIO2'].describe())

# Estadísticas de HR
print(f"\nEstadísticas de HR:")
print(df_imputado_completo['Solar8000/HR'].describe())

# Estadísticas de INCO2
print(f"\nEstadísticas de INCO2:")
print(df_imputado_completo['Solar8000/INCO2'].describe())

# Estadísticas de RR_CO2
print(f"\nEstadísticas de RR_CO2:")
print(df_imputado_completo['Solar8000/RR_CO2'].describe())

# Estadísticas de VENT RR
print(f"\nEstadísticas de VENT RR:")
print(df_imputado_completo['Solar8000/VENT_RR'].describe())

# Estadísticas de PLETH_SPO2
print(f"\nEstadísticas de PLETH_SPO2:")
print(df_imputado_completo['Solar8000/PLETH_SPO2'].describe())

# Estadísticas de PLETH_HR
print(f"\nEstadísticas de PLETH_HR:")
print(df_imputado_completo['Solar8000/PLETH_HR'].describe())

# Estadísticas de VENT PIP
print(f"\nEstadísticas de VENT PIP:")
print(df_imputado_completo['Solar8000/VENT_PIP'].describe())

# Estadísticas de VENT TV
print(f"\nEstadísticas de VENT TV:")
print(df_imputado_completo['Solar8000/VENT_TV'].describe())

# Estadísticas de MAC
print(f"\nEstadísticas de MAC:")
print(df_imputado_completo['Primus/MAC'].describe())

# Estadísticas de casos
print(f"\nEstadísticas de casos:")
print(df_imputado_completo['caseid'].describe())
# Out:
# Estadísticas de ETCO2:
# count    1.075328e+06
# mean     3.209797e+01
# std      1.013698e+01
# min      0.000000e+00
# 25%      3.200000e+01
# 50%      3.400000e+01
# 75%      3.700000e+01
# max      8.700000e+01
# Name: Solar8000/ETCO2, dtype: float64
#
# Estadísticas de FEO2:
# count    1.075328e+06
# mean     6.542555e+01
# std      1.946535e+01
# min      1.100000e+01
# 25%      5.000000e+01
# 50%      6.900000e+01
# 75%      8.400000e+01
# max      1.000000e+02
# Name: Solar8000/FEO2, dtype: float64
#
# Estadísticas de FIO2:
# count    1.075328e+06
# mean     7.147395e+01
# std      2.000520e+01
# min      1.200000e+01
# 25%      5.600000e+01
# 50%      7.500000e+01
# 75%      9.100000e+01
# max      1.000000e+02
# Name: Solar8000/FIO2, dtype: float64
#
# Estadísticas de HR:
# count    1.075328e+06
# mean     7.284427e+01
# std      1.762043e+01
# min      0.000000e+00
# 25%      6.200000e+01
# 50%      7.100000e+01
# 75%      8.200000e+01
# max      2.590000e+02
# Name: Solar8000/HR, dtype: float64
#
# Estadísticas de INCO2:
# count    1.075328e+06
# mean     8.469453e-01
# std      1.396401e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      6.200000e+01
# Name: Solar8000/INCO2, dtype: float64
#
# Estadísticas de RR_CO2:
# count    1.075328e+06
# mean     1.354951e+01
# std      4.157634e+00
# min      0.000000e+00
# 25%      1.200000e+01
# 50%      1.400000e+01
# 75%      1.600000e+01
# max      7.000000e+01
# Name: Solar8000/RR_CO2, dtype: float64
#
# Estadísticas de VENT RR:
# count    1.075328e+06
# mean     1.339945e+01
# std      4.590243e+00
# min      0.000000e+00
# 25%      1.200000e+01
# 50%      1.400000e+01
# 75%      1.600000e+01
# max      7.000000e+01
# Name: Solar8000/VENT_RR, dtype: float64
#
# Estadísticas de PLETH_SPO2:
# count    1.075328e+06
# mean     9.880375e+01
# std      3.855536e+00
# min      2.700000e+01
# 25%      9.900000e+01
# 50%      1.000000e+02
# 75%      1.000000e+02
# max      1.000000e+02
# Name: Solar8000/PLETH_SPO2, dtype: float64
#
# Estadísticas de PLETH_HR:
# count    1.075328e+06
# mean     7.371460e+01
# std      2.019309e+01
# min      4.000000e+00
# 25%      6.200000e+01
# 50%      7.100000e+01
# 75%      8.200000e+01
# max      3.000000e+02
# Name: Solar8000/PLETH_HR, dtype: float64
#
# Estadísticas de VENT PIP:
# count    1.075328e+06
# mean     2.031542e+01
# std      7.105559e+00
# min     -4.000000e+00
# 25%      1.700000e+01
# 50%      2.000000e+01
# 75%      2.300000e+01
# max      8.000000e+01
# Name: Solar8000/VENT_PIP, dtype: float64
#
# Estadísticas de VENT TV:
# count    1.075328e+06
# mean     3.258655e+02
# std      1.250325e+02
# min      1.000000e+01
# 25%      2.750000e+02
# 50%      3.310000e+02
# 75%      3.860000e+02
# max      2.960000e+03
# Name: Solar8000/VENT_TV, dtype: float64
#
# Estadísticas de MAC:
# count    1.075328e+06
# mean     1.770502e-02
# std      1.166313e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.100000e+00
# Name: Primus/MAC, dtype: float64
#
# Estadísticas de casos:
# count    1.075328e+06
# mean     3.204699e+03
# std      1.892280e+03
# min      7.000000e+00
# 25%      1.555000e+03
# 50%      3.205000e+03
# 75%      4.915000e+03
# max      6.376000e+03
# Name: caseid, dtype: float64

# %% [markdown]
# Al comparar estadísticas puedo notar que luego de la imputacion los valores promedio de casi todas las variable son un poco menores, pero en cantidades mínimas, de lo que deduzco que la imputación de datos no afecta de manera crítica ni significativa el contenido de mi data.
#
# -->> Voy a exportar los archivos resultantes hasta ahora: cirugias_VUP_filtrado y df_imputado_completo a formato CSV.

# %%
# Exportar el dataset limpio que tengo hasta este momento, en formato CSV
cirugias_VUP_filtrado2.to_csv('cirugias_VUP2.csv', index=False)
# Exportar el dataset limpio que tengo hasta este momento, en formato CSV
df_imputado_completo.to_csv('vitals2.csv', index=False)

# %% [markdown]
# ## Combinación de las tablas Cirguías (información estática) + Vitals (series de tiempo)

# %%
# Realizar la combinación de los dos DataFrames
datos_completos = pd.merge(df_imputado_completo, cirugias_VUP_filtrado2, on='caseid', how='left')

# Mostrar la nueva estructura del DataFrame
print("Estructura del DataFrame combinado:")
datos_completos.info()
# Out:
# Estructura del DataFrame combinado:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1075328 entries, 0 to 1075327
# Data columns (total 48 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Solar8000/ETCO2       1075328 non-null  float64
#  1   Solar8000/FEO2        1075328 non-null  float64
#  2   Solar8000/FIO2        1075328 non-null  float64
#  3   Solar8000/HR          1075328 non-null  float64
#  4   Solar8000/INCO2       1075328 non-null  float64
#  5   Solar8000/RR_CO2      1075328 non-null  float64
#  6   Solar8000/PLETH_SPO2  1075328 non-null  float64
#  7   Solar8000/PLETH_HR    1075328 non-null  float64
#  8   Solar8000/VENT_PIP    1075328 non-null  float64
#  9   Solar8000/VENT_TV     1075328 non-null  float64
#  10  Solar8000/VENT_RR     1075328 non-null  float64
#  11  Primus/MAC            1075328 non-null  float64
#  12  caseid                1075328 non-null  int64
#  13  casestart             1075328 non-null  int64
#  14  caseend               1075328 non-null  int64
#  15  anestart              1075328 non-null  int64
#  16  aneend                1075328 non-null  float64
#  17  age                   1075328 non-null  int64
#  18  sex                   1075328 non-null  object
#  19  height                1075328 non-null  float64
#  20  weight                1075328 non-null  float64
#  21  bmi                   1075328 non-null  float64
#  22  asa                   1075328 non-null  float64
#  23  emop                  1075328 non-null  int64
#  24  department            1075328 non-null  object
#  25  approach              1075328 non-null  object
#  26  position              1075328 non-null  object
#  27  ane_type              1075328 non-null  object
#  28  preop_htn             1075328 non-null  int64
#  29  preop_dm              1075328 non-null  int64
#  30  preop_ecg             1075328 non-null  object
#  31  preop_pft             1075328 non-null  object
#  32  preop_hb              1075328 non-null  float64
#  33  dltubesize            1075328 non-null  object
#  34  intraop_rbc           1075328 non-null  int64
#  35  intraop_ffp           1075328 non-null  int64
#  36  intraop_ppf           1075328 non-null  int64
#  37  intraop_mdz           1075328 non-null  float64
#  38  intraop_ftn           1075328 non-null  int64
#  39  intraop_rocu          1075328 non-null  int64
#  40  intraop_vecu          1075328 non-null  int64
#  41  intraop_eph           1075328 non-null  int64
#  42  intraop_phe           1075328 non-null  int64
#  43  intraop_epi           1075328 non-null  int64
#  44  intraop_ca            1075328 non-null  int64
#  45  dur_op_seg            1075328 non-null  int64
#  46  dur_anest_seg         1075328 non-null  float64
#  47  dur_case_seg          1075328 non-null  int64
# dtypes: float64(20), int64(20), object(8)
# memory usage: 393.8+ MB

# %%
#Almaceno los datos completos antes de empezar a preparar datos para modelos
datos_completos.to_csv('dataset_fuente_completo2.csv', index=False)
